# %%
#####################################################################################################################################
##### This script evaluates the performance of the LemonIte network against PKN
##### This will be done in two different approaches:
#####       1. Classic evaluation metrics (accuracy, precision, recall, F1-score) of LemonIte network against the ground truth data
#####       2. Evaluation of average shortest paths for metabolite-gene pairs from LemonIte network in the PKN
#####################################################################################################################################

# %%
# import modules and set working directory
import os
import pandas as pd
import numpy as np
import networkx as nx
from multiprocessing import Pool
from scipy.stats import hypergeom
from adjustText import adjust_text
import matplotlib.pyplot as plt
import seaborn as sns

base_dir = '/home/borisvdm/Documents/PhD/Lemonite/Lloyd-Price_IBD/results/'
run_id = 'LemonTree/'
percentile = 2
n_modules = 'selected_86'
    
workdir = base_dir + run_id
os.chdir(workdir)

dataset_file = workdir + f'/Preprocessing/LemonPreprocessed_complete.txt'
lemonnetwork_file = workdir + f'/Networks/LemonNetwork_percentile{percentile}_{n_modules}modules.txt'
PKNnetwork_file = '/home/borisvdm/Documents/PhD/Lemonite/PKN/Lemonite_PKN.tsv'
annotated_mets = '/home/borisvdm/Documents/PhD/gut_brain/IBD/Lloyd-Price2019/data/name_map.txt' # paste metabolite list in MetaboAnalyst id mapping tool and download result + manually look into annotations
#metabolite_interactions_file = workdir + f'PKN/HMDB_metabolites_gene_interactions.tsv'


TF_regulator_file = workdir+'ModuleViewer_files/Lovering.percentile'+str(percentile)+'_list.txt'
metabolite_regulator_file = workdir+'ModuleViewer_files/Metabolite.percentile'+str(percentile)+'_list.txt'
metabolite_random_regulator_file = workdir+'ModuleViewer_files/Metabolite.randomreg_list.txt'
clusterfile = workdir+'Lemon_out/clusters_list.txt'
metabolite_interactions_file = '/home/borisvdm/Documents/PhD/Lemonite/PKN/HMDB_metabolites_gene_interactions.csv'

# %% [markdown]
# # Read predicted network and create some dictionaries to map modules to genes, regulators to genes, etc

# %%
lemonnetwork = pd.read_csv(lemonnetwork_file, sep='\t')
lemonnetwork
lemonnetwork_metabolites = lemonnetwork[lemonnetwork['Type'] == 'Metabolite-gene']
print(lemonnetwork_metabolites)
# create dict with metabolite-gene interactions
metabolites2genes = {}
for index, row in lemonnetwork_metabolites.iterrows():
    if row['Regulator'] not in metabolites2genes:
        metabolites2genes[row['Regulator']] = [row['Target']]
    else:
        metabolites2genes[row['Regulator']].append(row['Target'])

genes_in_dataset = lemonnetwork['Target'].unique()
print(f'There are {len(genes_in_dataset)} genes in the dataset')
# Out:
#                   Regulator    Target     Score  Lemon_module             Type
# 18170             C20_1_LPC    IL27RA  0.270049             0  Metabolite-gene
# 18171             C20_1_LPC     IL21R  0.270049             0  Metabolite-gene
# 18172             C20_1_LPC      CD28  0.270049             0  Metabolite-gene
# 18173             C20_1_LPC   PPP1R18  0.270049             0  Metabolite-gene
# 18174             C20_1_LPC     SASH3  0.270049             0  Metabolite-gene
# ...                     ...       ...       ...           ...              ...
# 41357  C36_4_PC_plasmalogen    HOXA11  0.127858            95  Metabolite-gene
# 41358  C36_4_PC_plasmalogen   C8orf48  0.127858            95  Metabolite-gene
# 41359  C36_4_PC_plasmalogen   SLC22A3  0.127858            95  Metabolite-gene
# 41360  C36_4_PC_plasmalogen  ADAMTS14  0.127858            95  Metabolite-gene
# 41361  C36_4_PC_plasmalogen     TRPC3  0.127858            95  Metabolite-gene
#
# [23192 rows x 5 columns]
# There are 3543 genes in the dataset

# %%
# Funtion to create a dictionary with all regulators per module (start from the regulators.fold file created using LemonTree_downstream.py)
def get_regulators(regfile):
    regs = {}
    with open(regfile) as f:
        for line in f:
            module = line.split('\t')[0]
            regulators = line.rstrip().split('\t')[1].split('|')
            regs[module] = regulators
    return regs

module2TFs = get_regulators(TF_regulator_file)
module2mets = get_regulators(metabolite_regulator_file)
module2genes = get_regulators(clusterfile)
module2mets_random = get_regulators(metabolite_random_regulator_file)

print('modules:', module2genes)
print('TFs:', module2TFs)
print('mets:', module2mets)
print('mets_random:', module2mets_random)
# Out:
# modules: {'0': ['IL27RA', 'IL21R', 'CD28', 'PPP1R18', 'SASH3', 'HLA-DOB', 'CD3D', 'WDFY4', 'AGAP2', 'TIGIT', 'NCKAP1L', 'MAP4K1', 'SCIMP', 'LBH', 'NCF1', 'CD53', 'CD79A', 'PHACTR1', 'CD48', 'ITGAL', 'CYTIP', 'POU2F2', 'RASAL3', 'SPOCK2', 'ICOS', 'PTPN7', 'FGD2', 'TLR6', 'HLA-DOA', 'SP140', 'BTK', 'SLAMF6', 'LTA', 'CORO1A', 'IKZF1', 'ACAP1', 'IL16', 'AIM2', 'LCK', 'TRAF3IP3', 'PPP1R16B', 'FMNL3', 'DOK3', 'ARHGDIB', 'CD180', 'PCED1B', 'SNX20', 'WIPF1', 'P2RY10', 'CD52', 'PARVG', 'PYHIN1', 'GMFG', 'RAC2', 'RASGRP1', 'JAK3', 'ANKRD44', 'PRKCB', 'SH2D3C', 'DENND1C', 'TRAF1', 'LAT2', 'APBB1IP', 'NLRC3', 'CARD11', 'LCP1', 'WAS', 'RHOH', 'SUSD3', 'GRAP', 'ARHGAP25', 'TMEM156', 'FAM78A', 'PLCG2', 'P2RY8', 'PTPRC', 'SELL', 'FGD3', 'ARHGAP15', 'RUNX3', 'KLHL6', 'ADAM19', 'ZNF831', 'DOCK2', 'RFTN1', 'RASSF2', 'KMO', 'SH2D1A', 'LIMD2', 'MYO1G', 'FMNL1', 'NFATC1', 'ARHGAP30', 'ITK', 'CD5', 'TNFSF8', 'HCLS1', 'PIK3CD', 'ARHGAP9', 'CD6'], '1': ['ITGA5', 'ARHGEF15', 'RGCC', 'THSD1', 'LOXL2', 'PCDH17', 'IGFBP5', 'SNCAIP', 'TNC', 'RGS5', 'MEOX1', 'MGP', 'SORCS2', 'COL4A2', 'ANGPTL2', 'MCAM', 'C1R', 'ADAMTS6', 'GPR176', 'CSGALNACT1', 'MMP19', 'THY1', 'APLNR', 'CDH5', 'ROBO4', 'COL6A3', 'COL7A1', 'FEZ1', 'ECSCR', 'GJC1', 'FIBIN', 'CD34', 'CD93', 'COL4A1', 'HTRA3', 'RBPMS', 'OSMR', 'KDR', 'CTSK', 'CLEC14A', 'VWF', 'ARHGAP23', 'PDE10A', 'ANGPT2', 'BGN', 'KIFC3', 'HGF', 'F2R', 'GPR68', 'DYSF', 'TMEM255B', 'CTHRC1', 'TIE1', 'SERPINI1', 'NOVA2', 'ENG', 'NOTCH4', 'ADAMTS2', 'CPXM1', 'HEG1', 'IGFBP7', 'LDLRAD3', 'RAMP3', 'TUBB6', 'ADAMTS12', 'SGIP1', 'FSTL1', 'OLFML2B', 'MSC', 'CLEC1A', 'ENTPD1'], '2': ['CLCN2', 'SLC26A3', 'B3GNT8', 'EDN3', 'GUCA2B', 'CHP2', 'GUCA2A', 'MYH7B', 'ENTPD5', 'NAAA', 'CNNM2', 'MAOA', 'VIPR1', 'LRRN2', 'TMEM236', 'PBLD', 'ABCG2', 'MOGAT2', 'PPARGC1A', 'SGK2', 'LTK', 'FRMD1', 'SLC17A4', 'ACOX1', 'UGT1A1', 'HMGCS2', 'MEP1A', 'RUNDC3B', 'CA2', 'TRPM6', 'AHCYL2', 'SLC39A5', 'FXYD3', 'TMIGD1', 'IGSF9', 'SULT1A1', 'SLC35G1', 'AQP8', 'LANCL3', 'CDC14A', 'RHOU', 'ISX', 'PRKG2', 'CA1', 'PIGZ', 'EPHX2', 'PLCD3', 'PLA2G12B', 'PCK1', 'FABP1', 'SLC25A34', 'PAQR5', 'RIMKLA', 'TNNC2', 'DHRS11', 'PRDX6', 'FGFR2', 'OAF', 'PHLPP2', 'SULT1A2', 'SLC9A2', 'LRRC31', 'PADI2', 'TINCR', 'INPP5J', 'SELENBP1', 'CCNJL', 'CHAD', 'SLC4A4', 'UGT1A10', 'BMP3', 'PDE6A', 'CNTFR', 'SLC30A10', 'LRRC19', 'TMEM63C', 'SLC22A5', 'AQP7', 'ACSF2', 'OTOP2', 'PLCD1', 'WSCD1', 'ADH1C', 'TUBAL3', 'FGFR3', 'NEURL1B', 'SLC16A1', 'ANK3', 'CNGA1', 'ZNF575', 'FMO5', 'AIFM3', 'SLC26A2', 'SLC36A1', 'ITPKA', 'C2orf88', 'RNF152', 'TEX11', 'SOWAHA', 'ABCB1', 'CA12', 'CDKN2B', 'PKIB'], '3': ['CHST2', 'CIITA', 'SIGLEC10', 'APOBEC3G', 'MMP9', 'BCL2A1', 'TRIM22', 'VNN2', 'IL2RA', 'ADA', 'SLA', 'THEMIS2', 'STX11', 'SLC6A6', 'TNF', 'GBP5', 'SRGN', 'SEMA7A', 'IL4I1', 'CFP', 'BATF', 'TNFAIP2', 'FSCN1', 'ARID5A', 'S1PR1', 'SERPINB9', 'FGR', 'CSF2RB', 'LST1', 'FAM20A', 'PDE4B', 'MX2', 'BASP1', 'PTAFR', 'FOXP3', 'LAMP3', 'LILRB4', 'TRIB2', 'PLEK', 'SPI1', 'GPR132', 'PLEKHG2', 'PLEKHO1', 'TREML2', 'LAG3', 'RELT', 'ITGB2', 'LILRB1', 'TNFRSF8', 'HAPLN3', 'ADAM8', 'IL12RB1', 'HLA-DMB', 'CHI3L2', 'HLA-DRA', 'BCL6', 'CD80', 'SH2B2', 'CTLA4', 'TAGAP', 'CD74', 'CD40', 'ITGAX', 'MAPK11'], '4': ['SGCE', 'PDGFRA', 'EFEMP2', 'MXRA5', 'CNNM1', 'FLRT2', 'TMEM47', 'COL13A1', 'FIGN', 'ZNF536', 'COL6A2', 'MCC', 'BMP4', 'CDH6', 'NLGN2', 'ARHGAP28', 'GPC6', 'DSEL', 'TSHZ2', 'EML1', 'FOXF1', 'MAPK10', 'AMPH', 'FAM171B', 'SNAI2', 'LAMA4', 'NUDT11', 'DKK3', 'FBLN1', 'NOTCH3', 'COL3A1', 'FOXF2', 'VSTM4', 'DLC1', 'ECM1', 'FBXL7', 'GRID1', 'IGDCC4', 'ITGA8', 'DZIP1', 'COL4A5', 'STON1', 'COL12A1', 'LOX', 'FBN1', 'COL1A1', 'SULF1', 'C14orf132', 'CAV1', 'DPYSL3', 'PAMR1', 'AEBP1', 'CCDC80', 'GLI1', 'CD109', 'LRRC32', 'CNTNAP1', 'NXN', 'SPARCL1', 'ARHGAP6', 'FERMT2', 'MMP2', 'CALD1', 'DDR2', 'MAB21L2', 'CLMP', 'PCDH18', 'COL5A1', 'GLI2', 'TNXB', 'GLT8D2', 'EHD2', 'PCDH7', 'OLFML2A', 'MFAP4', 'MRC2', 'SGCD', 'BOC', 'PDGFRB', 'COL4A6', 'MAP1A', 'GDNF', 'FKBP10', 'ABCC9', 'SLC16A2', 'LUM', 'NR2F1', 'TUB', 'NEGR1', 'C1S', 'FR ...
# TFs: {'0': ['SP140'], '1': ['SKIL', 'SMAD3', 'ZNF532', 'ZNF98', 'NFE2L3', 'TSHZ2', 'ETV4', 'MKX'], '10': ['SP140', 'HSF5', 'EBF1', 'PRDM1'], '11': ['TCF7L1', 'SALL2', 'MEIS3', 'ZBTB47', 'SMAD4', 'ZNF587', 'CDC5L', 'NKX2-3'], '12': ['RFX6'], '13': ['JPH2'], '14': ['CSRNP3', 'ZNF536', 'HOXA11', 'ZNF280D', 'EPAS1'], '15': ['ZNF671', 'NFATC2', 'ZNF532', 'ZNF512B', 'SP140', 'NFE2L2', 'RUNX2', 'RFX5', 'MKX'], '16': ['ZNF362', 'ZNF704', 'CEBPG', 'TP53', 'RFX6', 'RARA', 'NEUROG3', 'ZNF384', 'ZNF613'], '17': ['ZNF521', 'TGIF1', 'SKIL', 'RARA', 'SP3', 'ZNF24'], '18': ['OSR1', 'ZFHX4', 'TCF21'], '19': ['SMAD3', 'PBX3', 'ZBTB47', 'ZNF521', 'GATA4', 'FOSB', 'TEAD4', 'RUNX2'], '2': ['ETV1', 'CREB3L2', 'POU2F1', 'SKIL', 'PRDM4'], '20': ['SPI1', 'NFATC3', 'SP140', 'NFKB2', 'ELF2'], '21': ['RFX6', 'HOXD12', 'HOXD11', 'EVX2'], '22': ['TWIST1', 'CREBZF', 'MYRF', 'AEBP1'], '23': ['STAT3', 'ERF', 'ZFHX3', 'ZNF704'], '24': ['EBF4', 'TCF7L1', 'GLIS2', 'NKX2-3', 'ZNF853', 'MEIS3', 'SMAD4'], '25': ['CEBPB', 'STAT3', 'HAND2', 'STAT5B', 'ISX', 'ETV1'], '26': ['ZNF704', 'MXD1', 'ZNF493', 'MAFA', 'ZFHX3', 'ZFP3'], '27': ['HNF4A', 'NR1H4', 'ZFHX3', 'FOXN3', 'LHX4', 'STAT5B'], '28': ['PAX8', 'HOXD12', 'BHLHE41', 'NR1I2', 'HNF1A'], '29': ['SALL2', 'PKNOX2', 'ZNF512B', 'FOXN1', 'ZNF853', 'MYT1'], '3': ['SPI1', 'FOXP1'], '30': ['ZNF692', 'ZNF354B', 'PBX4', 'THRA'], '31': ['TWIST1', 'STOX2', 'MYRF', 'HOXA11', 'HOXB9', 'RORA', 'ZNF536'], '32': ['ZNF414', 'ZNF524', 'ZNF628', 'ZBTB45'], '33': ['GLI4', 'ZNF789', 'ZBTB49'], '34': ['TFEC', 'ZNF366', 'ZIC1', 'FOXP3'], '35': ['ZNF536', 'PKNOX2', 'FOXL1', 'ZFHX4', 'SALL2'], '36': ['HOXD11', 'HOXD10', 'ONECUT2'], '37': ['ZNF692'], '38': ['HNF4G', 'NR2F6', 'HEY2', 'NR6A1', 'MEIS3', 'ZFP69', 'ZFHX4'], '39': ['ZBTB10', 'ZNF704', 'ETS2', 'BCL6', 'GATA4'], '4': ['TSHZ3', 'ZNF532', 'FOXL1', 'SOX9', 'PKNOX2', 'CREB3L2', 'CREB3L3', 'RARG', 'HOXB5'], '40': ['MYRFL'], '41': ['ZNF257', 'ZNF793', 'ZNF626'], '42': ['ZNF664', 'SNAI3'], '43': ['MEIS3', 'PKNOX2', 'SP3', 'TSHZ3', 'ZNF521'], '44': ['GATA5', 'ZNF613', 'NEUROG3', 'IRF7', 'ESRRA', 'TEAD3'], '45': ['CREB3L2', 'MAFA', 'ZFHX3', 'BATF2', 'DMRTA1'], '46': ['ATF5', 'PLSCR1', 'MEIS1', 'IRF1'], '47': ['ZBTB7C', 'ZIC1'], '48': ['ZNF354B', 'ZNF10', 'ZNF345', 'ZNF660', 'ZNF711', 'ZNF251', 'ZNF550'], '49': ['PURA', 'RFX6', 'TEAD3', 'ZNF443', 'STAT3'], '5': ['SP140', 'EBF1', 'PRDM1', 'ZNF101', 'PAX5'], '50': ['PAX5', 'EBF1', 'ZNF263'], '51': ['ZNF667', 'IRX6'], '52': ['TSHZ2', 'MIXL1', 'ZNF532', 'XBP1'], '53': ['MIXL1', 'JUNB', 'RARG', 'STOX2', 'HSF1', 'FOSB', 'SOX9'], '54': ['REST', 'TCF21'], '55': ['ISL1', 'SP5', 'FOXP2', 'EVX2', 'SMAD2', 'KLF11', 'ATMIN'], '56': ['RFX6', 'OSR1', 'NEUROG3', 'MEIS1'], '57': ['SOX8', 'DRGX'], '58': ['LMX1A', 'CREB1', 'CSRNP1', 'DMTF1'], '59': ['ERG', 'HOXB7', 'SKIL', 'FOXJ3', 'ZNF436', 'ELF2', 'PBX4', 'ZNF76', 'MITF'], '6': ['SMAD3', 'GLIS2', 'EGR2', 'TGIF1', 'SMAD4', 'GATA4', 'ZNF91'], '60': ['SOX10', 'HOXD9', 'ZNF518A', 'ZSCAN18'], '61': ['ZIK1', 'TFEC', 'ZNF304', 'RARG', 'ZNF532'], '62': ['SKIL', 'ZNF512B', 'FOXS1', 'EGR1', 'ELF2', 'SMAD3', 'BCL6B', 'TCF3'], '63': ['EVX2', 'HOXD11', 'HOXD12', 'HNF1A'], '64': ['MAFF', 'ZNF606'], '65': ['ZNF518B', 'IRX3', 'IRX5', 'ZNF418', 'GABPA'], '66': ['SMAD4', 'GLI1'], '67': ['HMX3', 'HMX2', 'PURA', 'ZNF844'], '68': ['FOXJ3', 'ZNF808', 'ZNF28', 'ETV1', 'ZNF362', 'ZNF440', 'GLI1', 'ZHX1', 'ZNF587', 'ZNF233'], '69': ['HNF4G'], '7': ['CEBPD', 'STAT3', 'IRF6', 'ZNF620', 'ATF2'], '70': ['HNF4A', 'NR1I2', 'TAL1', 'ZNF57', 'HSF1'], '71': ['ZFHX3', 'ZBTB17', 'ATF6'], '72': ['ONECUT2', 'ZNF492', 'ZNF677'], '73': ['ZNF644', 'ZNF41', 'ZNF124'], '74': ['TSHZ3', 'MAFB', 'SPIB', 'SOX7'], '75': ['STAT3', 'ELF3', 'ETV4', 'IRF6', 'SOX7'], '76': ['ZSCAN18', 'GRHL2', 'ZNF768', 'CREB3L2', 'OVOL2', 'ZNF438'], '77': ['HOXA11', 'CREBL2'], '78': ['JPH2', 'TCF21', 'SALL2', 'EBF3', 'MEF2D', 'OSR2'], '79': ['PRDM16', 'SP3', 'ETV4', 'ZNF613', 'RFX6'], '8': ['SP140', 'BATF', 'NFATC2', 'ELF2', 'SPI1', 'RUNX1', 'GATA3'], '80': ['ZNF19', 'ZNF334' ...
# mets: {'0': ['C20_1_LPC', 'C14_carnitine', 'C22_1_SM', 'C36_4_PC_plasmalogen', 'C16_1_SM', 'C18_0_LPE_A', 'C20_0_LPE', 'C16_1_LPC_plasmalogen', 'C20_0_SM', 'C18_1_SM'], '1': ['C56_1_TAG', 'putrescine', 'C16_1_SM', '1_methylnicotinamide', 'C56_2_TAG', 'N1_acetylspermidine', 'C24_1_SM', 'C22_5_CE_[M_NH4]_', 'C14_carnitine'], '10': ['adrenate', 'C18_2_carnitine', 'C22_1_SM', 'C14_1_carnitine', 'N2_N2_dimethylguanosine'], '11': ['threosphingosine', 'C52_7_TAG', 'C14_carnitine', 'cadaverine', 'gabapentin', 'sphingosine', 'sphingosine_isomer3', '2_aminoheptanoic_acid'], '12': ['C36_4_PC_plasmalogen', 'C18_0_LPE_A', 'caproate', 'C44_1_TAG', 'C18_0_LPC', 'C20_1_LPC', 'C18_1_LPE'], '13': ['5_aminolevulinic_acid', 'C52_0_TAG_[M_NH4]_', 'N_methylproline', 'hyodeoxycholate/ursodeoxycholate', 'agmatine', 'hexadecanedioate', 'N1_acetylspermidine', 'gabapentin'], '14': ['imidazoleacetic_acid', 'C18_1_LPC_plasmalogen', 'kynurenic_acid', 'C16_0_SM', 'eicosadienoate'], '15': ['adrenate', 'C14_carnitine', 'C22_1_SM', 'beta_alanine', 'N6_N6_dimethyllysine', 'hyodeoxycholate/ursodeoxycholate', '4_aminophenol'], '16': ['C2_carnitine', 'C18_1_LPC_plasmalogen', 'C18_0_LPC', 'alpha_glycerophosphocholine', 'C36_4_PC_plasmalogen', 'C18_0_LPE_A'], '17': ['carnosol', 'C18_0_CE', 'putrescine', 'ketodeoxycholate', 'C18_0_CE_[M_NH4]_', 'C20_1_LPC'], '18': ['serotonin', 'C20_1_LPC', 'C18_0_LPE_A', 'C36_4_PC_plasmalogen', 'C18_0_LPC', 'C18_0_LPE'], '19': ['gabapentin', 'metronidazole', 'C22_1_SM', 'C22_5_CE_[M_NH4]_', 'acetyl_galactosamine', 'hippurate', 'theophylline', 'C38_3_PC', 'choline'], '2': ['C2_carnitine', 'alpha_glycerophosphocholine', 'C18_0_LPE', 'C18_1_LPC_plasmalogen', 'C46_2_TAG', 'C34_0_PC', 'C16_0_SM', 'glycine', '2_aminoheptanoic_acid', 'C22_1_SM', '21_deoxycortisol'], '20': ['C20_1_LPC', 'C20_0_SM', 'C22_1_SM', 'C18_1_LPC_plasmalogen', 'C16_1_LPC_plasmalogen', 'C20_5_LPC', 'C18_2_LPC', 'adrenate', '4_aminophenol', 'C18_1_SM', 'C18_2_LPE'], '21': ['C18_0_LPC', 'C18_0_LPE_A', 'C36_4_PC_plasmalogen', '2_hydroxyoctanoate', 'C16_1_LPC'], '22': ['butyrobetaine', 'C18_1_LPC_plasmalogen', 'linoleate', 'anserine', '5_aminolevulinic_acid', 'C44_0_TAG_[M_NH4]_'], '23': ['C18_1_LPC_plasmalogen', 'C16_0_SM', 'crustecdysone', 'C50_0_TAG_[M_NH4]_', 'N_acetyalanine', 'alpha_glycerophosphocholine', 'C2_carnitine', 'C14_carnitine', 'salicylate'], '24': ['5_aminolevulinic_acid', 'piperine', 'carnosol_isomer', 'metformin', 'C16_1_LPE', 'trigonelline', 'C34_3_PC', 'sphingosine_isomer3'], '25': ['C18_1_LPC_plasmalogen', 'C18_0_LPE', 'C20_1_LPC', 'C34_0_PC', 'C16_1_MAG_[M_NH4]_'], '26': ['C2_carnitine', 'dodecanedioate', 'alpha_glycerophosphocholine', 'C18_1_LPE', 'C45_0_TAG'], '27': ['C36_4_PC_plasmalogen', 'carboxyibuprofen', 'C38_4_PC', 'C2_carnitine'], '28': ['agmatine', 'spermidine', 'trigonelline', 'pipecolic_acid'], '29': ['serotonin', 'quinine', 'C46_0_TAG_[M_NH4]_', 'salicylate', 'C42_0_TAG'], '3': ['C20_1_LPC', 'arachidate', 'C18_0_LPC', 'C22_1_SM', 'oleanate', 'C18_0_LPE', 'glycoursodeoxycholate'], '30': ['3_hydroxyoctanoate', 'ectoine', 'metronidazole'], '31': ['5_aminolevulinic_acid', 'C44_0_TAG_[M_NH4]_', 'C52_0_TAG_[M_NH4]_', 'phytanate', 'acetyl_galactosamine', 'C20_4_LPC'], '32': ['carnitine', 'dodecanoate', 'myristate', 'N1_methyl_2_pyridone_5_carboxamide', 'hydroxycotinine'], '33': ['5_aminolevulinic_acid', 'C32_0_PE', 'N_acetyalanine', 'C18_1_LPE', 'eicosanedioate', 'C18_2_LPC', 'C18_1_LPC'], '34': ['C14_carnitine', 'C2_carnitine', 'C3_carnitine', 'pentadecanoate', 'C20_1_LPC', 'C10_carnitine'], '35': ['anserine', 'carnosol_isomer', 'C50_4_TAG', '13_cis_retinoic_acid', 'serotonin', 'N_acetylglutamine', 'C38_5_DAG_[M_NH4]_'], '36': ['hexadecanedioate', 'C22_5_CE_[M_NH4]_'], '37': ['eicosadienoate', '3_hydroxyoctanoate', 'C51_2_TAG', 'cadaverine', '3^_O_methyladenosine'], '38': ['C42_0_TAG_[M_NH4]_', 'trimethylamine_N_oxide', 'C50_1_TAG_[M_NH4]_', 'biliverdin', 'C18_0_MAG_[M_NH4]_', 'C9_carnitine'], '39': ['C20_1_LPC', 'C24_0_SM', 'C38_4_PC'], '4 ...
# mets_random: {'0': ['homoarginine', 'N6_N6_dimethyllysine', 'docosapentaenoate', '5_acetylamino_6_amino_3_methyluracil', 'C18_0_LPE_A', 'C18_3_LPC', 'alpha_muricholate', 'C18_0_SM', 'ADMA/SDMA', 'C18_1_carnitine', 'C22_1_SM', 'imidazoleacetic_acid', 'C18_3_CE', 'stearate', 'adrenate', 'hippurate', 'agmatine', 'carboxyibuprofen', 'C38_4_PC_plasmalogen', 'C16_0_LPE', 'C18_1_LPC', 'C18_0_LPE_B', 'C18_2_LPC', 'inosine', 'cadaverine', 'C18_3_CE_[M_NH4]_', 'creatine', 'C38_2_PC', '12.13_diHOME', 'C38_4_DAG_[M_NH4]_', '4_aminophenol', '17_methylstearate', 'metronidazole', 'C20_4_CE_[M_NH4]_', 'C34_0_PC', 'C34_4_PC_plasmalogen', 'C24_0_SM', 'C38_4_PC', 'eicosenoate', 'C46_3_TAG', 'C20_1_LPC', 'eicosapentaenoate', 'C22_6_LPE', 'pentadecanoate', 'C49_1_TAG_[M_NH4]_', 'C20_4_LPC', 'C3_carnitine', 'C22_4_CE', 'taurochenodeoxycholate', 'linoleate', 'C20_5_CE_[M_NH4]_', 'bilirubin', 'C36_4_PC_plasmalogen', 'cholate', 'C36_2_PC_plasmalogen', 'methionine_sulfoxide', 'leucine', '13_docosenoate', 'C18_carnitine', '7_methylxanthine', 'C52_1_TAG_[M_NH4]_', 'methionine', 'alpha_linolenate', 'C32_0_PE', 'diacetylspermine', 'betaine', 'N1_acetylspermidine', 'C50_4_TAG_[M_NH4]_', 'C16_1_CE_[M_NH4]_', 'C18_1_LPC_plasmalogen', 'C18_2_CE', 'C18_1_SM', 'beta_sitosterol', '4_hydroxy_3_methylacetophenone', 'C16_1_LPC', 'dodecanedioate', 'putrescine', 'serotonin', 'indoleacetate', 'pipecolic_acid', 'C56_2_TAG', 'C24_0_Ceramide_(d18_1)', 'acetaminophen', 'anserine', 'taurodeoxycholate', 'N1_N12_diacetylspermine', 'tyrosine', 'deoxycholate', 'tauro_alpha_muricholate/tauro_beta_muricholate', 'C18_0_MAG', 'C16_1_CE', 'C16_1_SM', 'C14_2_carnitine', 'N6_N6_N6_trimethyllysine', '3_hydroxyoctanoate', 'C16_0_SM', 'palmitoylethanolamide', 'C56_7_TAG', 'acetylcholine', 'C20_5_CE', 'C48_0_TAG', 'C38_5_DAG_[M_NH4]_', 'C44_1_TAG', 'glycodeoxycholate', 'undecanedionate', 'alpha_CEHC', 'C50_4_TAG', 'C44_2_TAG_[M_NH4]_', 'C50_1_TAG_[M_NH4]_', 'p_hydroxyphenylacetate', 'C20_3_LPC', 'C20_4_CE', 'C36_4_DAG_[M_NH4]_', 'N_acetylhistidine', 'porphobilinogen', 'C34_0_PE', 'C14_0_SM', 'tryptophan', 'C46_0_TAG', 'C36_2_PC', 'C16_0_CE', 'glycolithocholate', 'C54_5_TAG_[M_NH4]_', 'C10_carnitine', 'histidinol', 'C36_2_DAG_[M_NH4]_', 'N1_methyl_2_pyridone_5_carboxamide', 'C53_2_TAG_[M_NH4]_', 'C20_5_LPC', '4_hydroxystyrene', 'taurine', 'phenylalanine', 'beta_alanine', 'C22_0_SM', 'C20_0_LPE', 'C34_3_PC', 'N_acetylornithine', 'histidine', 'C16_1_MAG_[M_NH4]_', 'C36_3_DAG', 'methylimidazole_acetic_acid', 'hydrocinnamate', 'piperine', 'C14_0_LPC', 'C36_1_PC', 'linoleoyl_ethanolamide', 'pterin', 'sphingosine_isomer3', 'C20_0_SM', 'C36_0_DAG', 'C18_2_carnitine', 'C32_1_DAG', 'isoleucine', 'C52_2_TAG', 'C22_0_Ceramide_(d18_1)', 'C50_5_TAG_[M_NH4]_', 'C36_3_PC', 'glycochenodeoxycholate', 'sphingosine_isomer1', 'C30_0_PC', 'azelate', 'N_acetyalanine', 'C56_6_TAG_[M_NH4]_', 'C16_0_Ceramide_(d18_1)', 'urobilin___targeted', 'taurohyodeoxycholate/tauroursodeoxycholate', 'C48_1_TAG', 'carnosol', 'C14_1_carnitine', 'C50_3_TAG', 'C48_1_TAG_[M_NH4]_', 'C52_1_TAG', '13_cis_retinoic_acid', 'C2_Ceramide_(d18_1)', 'citrulline', 'C51_3_TAG', 'C44_0_TAG', 'docosahexaenoate', 'C10_2_carnitine', 'C22_5_CE_[M_NH4]_', 'C12_1_carnitine', 'C22_1_MAG', 'C18_0_LPC', 'creatinine', 'saccharin', 'tetradecanedioate', '7_methylguanine', 'nonadecanoate', 'histamine', 'niacinamide', 'C52_2_TAG_[M_NH4]_', 'N_alpha_acetylarginine', 'C54_2_TAG_[M_NH4]_', 'C22_4_CE_[M_NH4]_', 'C16_0_LPC', 'C22_1_MAG_[M_NH4]_', 'oxymetazoline', 'lithocholate', 'chenodeoxycholate', 'adenosine', 'C22_5_CE', 'proline_betaine', 'aspartate', '2_aminoheptanoic_acid', 'C54_2_TAG', 'pantothenate', 'C2_carnitine', 'butyrobetaine', 'C34_1_PC_plasmalogen', 'taurocholate', 'hydroxycotinine', 'caffeine', 'C54_6_TAG', 'C14_0_CE', 'C58_10_TAG', 'C32_2_DAG_[M_NH4]_', '1_methylhistamine', 'C50_0_TAG_[M_NH4]_', '5_hydroxytryptophan', 'N_acetylhistamine', 'C52_0_TAG', 'phytanate', 'glycocholate', 'palmithoylethanolamide', 'C51_3_TAG_[M_NH4]_', 'glutamine', 'C36_4 ...

# %% [markdown]
# # Subset metabolite-gene interactions file for metabolites that are in the dataset

# %%
interactions = pd.read_csv(metabolite_interactions_file, sep='\t')
interactions
# Out:
# /tmp/ipykernel_214267/3026841620.py:1: DtypeWarning: Columns (15,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactions = pd.read_csv(metabolite_interactions_file, sep='\t')
#                               Name         HMDB    ChEBI    KEGG   PubChem  \
# 0                1-Methylhistidine  HMDB0000001  50599.0  C01152   92105.0
# 1               1,3-Diaminopropane  HMDB0000002  15725.0  C00986     428.0
# 2               2-Ketobutyric acid  HMDB0000005  30831.0  C00109      58.0
# 3            2-Hydroxybutyric acid  HMDB0000008  50613.0  C05984  440864.0
# 4                 2-Methoxyestrone  HMDB0000010   1189.0  C05299  440624.0
# ...                            ...          ...      ...     ...       ...
# 217915         Nordeoxycholic acid  HMDB0304947      NaN     NaN  314374.0
# 217916  3-Oxo-5beta-cholanoic acid  HMDB0304950      NaN     NaN  543448.0
# 217917        Glycerol 1-myristate  HMDB0304951  75562.0     NaN   79050.0
# 217918       O-Phenolsulfonic acid  HMDB0304953  71049.0     NaN   11867.0
# 217919                   d-Fucitol  HMDB0304954      NaN     NaN  445724.0
#
#                                                IUPAC_Name  \
# 0       (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)prop...
# 1                                     propane-1,3-diamine
# 2                                      2-oxobutanoic acid
# 3                             (2S)-2-hydroxybutanoic acid
# 4       (1S,10R,11S,15S)-5-hydroxy-4-methoxy-15-methyl...
# ...                                                   ...
# 217915  3-{5,16-dihydroxy-2,15-dimethyltetracyclo[8.7....
# 217916  4-{2,15-dimethyl-5-oxotetracyclo[8.7.0.0^{2,7}...
# 217917                 2,3-dihydroxypropyl tetradecanoate
# 217918                   2-hydroxybenzene-1-sulfonic acid
# 217919              (2R,3S,4R,5S)-hexane-1,2,3,4,5-pentol
#
#                                                    SMILES  \
# 0                             CN1C=NC(C[C@H](N)C(O)=O)=C1
# 1                                                   NCCCN
# 2                                           CCC(=O)C(O)=O
# 3                                        CC[C@H](O)C(O)=O
# 4       [H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[...
# ...                                                   ...
# 217915     CC(CC(O)=O)C1CCC2C3CCC4CC(O)CCC4(C)C3CC(O)C12C
# 217916      CC(CCC(O)=O)C1CCC2C3CCC4CC(=O)CCC4(C)C3CCC12C
# 217917                         CCCCCCCCCCCCCC(=O)OCC(O)CO
# 217918                             OC1=CC=CC=C1S(O)(=O)=O
# 217919  [H][C@@](C)(O)[C@@]([H])(O)[C@@]([H])(O)[C@]([...
#
#                            InChIKey PDB_ID                          Kingdom  \
# 0       BRMWTNUJHUMWMS-LURJTMIESA-N    NaN    Organic acids and derivatives
# 1       XFNJVJPLKCPIBV-UHFFFAOYSA-N    NaN       Organic nitrogen compounds
# 2       TYEYBOSBBBHJIV-UHFFFAOYSA-N    NaN    Organic acids and derivatives
# 3       AFENDNXGAFYKQO-VKHMYHEASA-N    NaN    Organic acids and derivatives
# 4       WHEUWNKSCXYKBU-QPWUGHHJSA-N    NaN  Lipids and lipid-like molecules
# ...                             ...    ...                              ...
# 217915  PLRQOCVIINWCFA-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217916  KIQFUORWRVZTHT-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217917  DCBSHORRWZKAKO-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217918  IULJSGIJJZZUMF-UHFFFAOYSA-N    NaN                       Benzenoids
# 217919  SKCKOFZKJLZSFA-KCDKBNATSA-N    NaN         Organic oxygen compounds
#
#         ... IntAct                                          UniProtKB chEMBL  \
# 0       ...   none                                               none   none
# 1       ...   none              DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS   none
# 2       ...   none  RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...   none
# 3       ...   none                                               none   none
# 4       ...   none     COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT   none
# ...     ...    ...                                                ...    ...
# 217915  ...   none                                               none   none
# 217916  ...   none                       DHRS4|SDR25C2|UNQ851/PRO1800   none
# 217917  ...   none  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...   none
# 217918  ...   none                                               none   none
# 217919  ...   none                                               none   none
#
#           LINCS STITCH BioGRID  \
# 0           NaN    NaN   ACTA1
# 1           NaN    NaN     NaN
# 2           NaN    NaN     NaN
# 3           NaN    NaN     NaN
# 4       HSD17B1    NaN     NaN
# ...         ...    ...     ...
# 217915      NaN    NaN     NaN
# 217916      NaN    NaN     NaN
# 217917      NaN    NaN     NaN
# 217918      NaN    NaN     NaN
# 217919      NaN    NaN     NaN
#
#                                          Human1_GEM_dist1  \
# 0                                                     NaN
# 1             AOC1|AOC2|AOC3|DHPS|SLC22A1|SLC22A2|SLC22A3
# 2       BCKDHA|BCKDHB|CTH|GPT|LDHAL6A|LDHAL6B|LDHB|LDH...
# 3                                                     NaN
# 4                                       ABCB1|COMT|LRTOMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                          Human1_GEM_dist2  \
# 0                                                     NaN
# 1       AADAC|AASDH|ABHD12|ABHD6|ACAA1|ACAA2|ACE|ACE2|...
# 2       AADAC|AADAT|ABAT|ABHD12|ABHD6|ACE|ACE2|ACHE|AC...
# 3                                                     NaN
# 4       AADAC|ABCB1|ABHD12|ABHD6|ACE|ACE2|ACHE|ACP2|AC...
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                               MetalinksDB  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4                                       UGT1A8|ABCB1|COMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                 All_database_interactions
# 0                                                   ACTA1
# 1       DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS|AOC1|AOC...
# 2       RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4       COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT...
# ...                                                   ...
# 217915                                                NaN
# 217916                       DHRS4|SDR25C2|UNQ851/PRO1800
# 217917  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...
# 217918                                                NaN
# 217919                                                NaN
#
# [217920 rows x 22 columns]

# %%
# contextualize metabolite-gene interactions to dataset
metabolite_mapping = pd.read_csv(annotated_mets, sep=',')
print(metabolite_mapping)
# Create a dictionary that maps Query to HMDB
metabolite_mapping = metabolite_mapping.set_index('Query')['HMDB'].dropna().to_dict()
print(metabolite_mapping)
metabolites_hmdb = metabolite_mapping.values()
print(f'{len(metabolites_hmdb)} metabolites in this dataset are mapped to a hmdb id')
# Out:
#                                           Query                  Match  \
# 0                               1_methylguanine                    NaN
# 1                             1_methylguanosine                    NaN
# 2                             1_methylhistamine                    NaN
# 3                          1_methylnicotinamide                    NaN
# 4                              21_deoxycortisol                    NaN
# ..                                          ...                    ...
# 465  taurohyodeoxycholate/tauroursodeoxycholate                    NaN
# 466                           taurolithocholate     Lithocholyltaurine
# 467                           tetradecanedioate  Tetradecanedioic acid
# 468                                theophylline           Theophylline
# 469                             undecanedionate     Undecanedioic acid
#
#             HMDB   PubChem    ChEBI    KEGG  METLIN  \
# 0            NaN       NaN      NaN     NaN     NaN
# 1            NaN       NaN      NaN     NaN     NaN
# 2            NaN       NaN      NaN     NaN     NaN
# 3            NaN       NaN      NaN     NaN     NaN
# 4            NaN       NaN      NaN     NaN     NaN
# ..           ...       ...      ...     ...     ...
# 465          NaN       NaN      NaN     NaN     NaN
# 466  HMDB0000722  439763.0  36259.0  C02592  5690.0
# 467  HMDB0000872   13185.0  76308.0  C11002  5833.0
# 468  HMDB0001889    2153.0  28177.0  C07130  1458.0
# 469  HMDB0000888   15816.0  73713.0     NaN  5846.0
#
#                                                 SMILES  Comment
# 0                                                  NaN        0
# 1                                                  NaN        0
# 2                                                  NaN        0
# 3                                                  NaN        0
# 4                                                  NaN        0
# ..                                                 ...      ...
# 465                                                NaN        0
# 466  [H][C@@]1(CC[C@@]2([H])[C@]3([H])CC[C@]4([H])C...        1
# 467                           OC(=O)CCCCCCCCCCCCC(O)=O        1
# 468                        CN1C2=C(NC=N2)C(=O)N(C)C1=O        1
# 469                              OC(=O)CCCCCCCCCC(O)=O        1
#
# [470 rows x 9 columns]
# {'acetaminophen': 'HMDB0001859', 'acetylcholine': 'HMDB0000895', 'adenosine': 'HMDB0000050', 'agmatine': 'HMDB0001432', 'alanine': 'HMDB0000161', 'alanylalanine': 'HMDB0028680', 'alloisoleucine': 'HMDB0000172', 'anserine': 'HMDB0000194', 'arginine': 'HMDB0000517', 'aspartate': 'HMDB0000191', 'atenolol': 'HMDB0001924', 'betaine': 'HMDB0000043', 'bilirubin': 'HMDB0000054', 'biliverdin': 'HMDB0001008', 'biotin': 'HMDB0000030', 'butyrobetaine': 'HMDB0001161', 'cadaverine': 'HMDB0002322', 'caffeine': 'HMDB0001847', 'carnitine': 'HMDB0000062', 'choline': 'HMDB0000097', 'citrulline': 'HMDB0000904', 'cortisol': 'HMDB0000063', 'cotinine': 'HMDB0001046', 'creatine': 'HMDB0000064', 'creatinine': 'HMDB0000562', 'cytidine': 'HMDB0000089', 'cytosine': 'HMDB0000630', 'diacetylspermine': 'HMDB0002172', 'dimethylglycine': 'HMDB0000092', 'ectoine': 'HMDB0240650', 'gabapentin': 'HMDB0005015', 'glutamate': 'HMDB0000148', 'glutamine': 'HMDB0000641', 'glycine': 'HMDB0000123', 'hippurate': 'HMDB0000714', 'histamine': 'HMDB0000870', 'histidine': 'HMDB0000177', 'histidinol': 'HMDB0253185', 'homoarginine': 'HMDB0000670', 'homocitrulline': 'HMDB0000679', 'hydroxycotinine': 'HMDB0001390', 'hydroxyproline': 'HMDB0000725', 'hypoxanthine': 'HMDB0000157', 'inosine': 'HMDB0000195', 'isoleucine': 'HMDB0000172', 'leucine': 'HMDB0000687', 'lysine': 'HMDB0000182', 'metformin': 'HMDB0001921', 'methionine': 'HMDB0000696', 'metronidazole': 'HMDB0015052', 'niacinamide': 'HMDB0001406', 'ornithine': 'HMDB0000214', 'pantothenate': 'HMDB0000210', 'phenylalanine': 'HMDB0000159', 'phytosphingosine': 'HMDB0004610', 'piperine': 'HMDB0029377', 'proline': 'HMDB0000162', 'pterin': 'HMDB0000802', 'putrescine': 'HMDB0001414', 'pyridoxine': 'HMDB0000239', 'quinine': 'HMDB0014611', 'serine': 'HMDB0000187', 'serotonin': 'HMDB0000259', 'spermidine': 'HMDB0001257', 'sphinganine': 'HMDB0000269', 'sulfapyridine': 'HMDB0015028', 'taurine': 'HMDB0000251', 'trigonelline': 'HMDB0000875', 'tryptophan': 'HMDB0000929', 'tyrosine': 'HMDB0000158', 'urobilin': 'HMDB0004160', 'valine': 'HMDB0000883', 'cholesterol': 'HMDB0000067', 'linoleoylethanolamide': 'HMDB0012252', 'sphingosine': 'HMDB0000252', 'acesulfame': 'HMDB0033585', 'adrenate': 'HMDB0002226', 'arachidate': 'HMDB0002212', 'arachidonate': 'HMDB0001043', 'azelate': 'HMDB0000784', 'caprate': 'HMDB0000511', 'caproate': 'HMDB0000535', 'carboxyibuprofen': 'HMDB0060564', 'carnosol': 'HMDB0002121', 'chenodeoxycholate': 'HMDB0000518', 'cholate': 'HMDB0000619', 'crustecdysone': 'HMDB0030180', 'deoxycholate': 'HMDB0000626', 'docosahexaenoate': 'HMDB0002183', 'docosapentaenoate': 'HMDB0001976', 'dodecanedioate': 'HMDB0000623', 'dodecanoate': 'HMDB0000638', 'eicosadienoate': 'HMDB0005060', 'eicosanedioate': 'HMDB0242141', 'eicosapentaenoate': 'HMDB0001999', 'eicosatrienoate': 'HMDB0002925', 'eicosenoate': 'HMDB0002231', 'furosemide': 'HMDB0001933', 'glycochenodeoxycholate': 'HMDB0000637', 'glycocholate': 'HMDB0000138', 'glycodeoxycholate': 'HMDB0000631', 'glycolithocholate': 'HMDB0000698', 'glycoursodeoxycholate': 'HMDB0000708', 'heptanoate': 'HMDB0304376', 'hexadecanedioate': 'HMDB0304377', 'hydrochlorothiazide': 'HMDB0001928', 'hydrocinnamate': 'HMDB0000764', 'indoleacetate': 'HMDB0000197', 'linoleate': 'HMDB0000673', 'lithocholate': 'HMDB0000717', 'mandelate': 'HMDB0000703', 'masilinate': 'HMDB0002392', 'myristate': 'HMDB0000806', 'myristoleate': 'HMDB0002000', 'nonadecanoate': 'HMDB0000772', 'oleanate': 'HMDB0002364', 'oleate': 'HMDB0000207', 'olmesartan': 'HMDB0014420', 'oxymetazoline': 'HMDB0015070', 'oxypurinol': 'HMDB0000786', 'palmitate': 'HMDB0000220', 'palmitoleate': 'HMDB0003229', 'palmitoylethanolamide': 'HMDB0002100', 'pentadecanoate': 'HMDB0000826', 'phenyllactate': 'HMDB0000563', 'phytanate': 'HMDB0000801', 'porphobilinogen': 'HMDB0000245', 'saccharin': 'HMDB0029723', 'salicylate': 'HMDB0000840', 'sebacate': 'HMDB0000792', 'stearate': 'HMDB0000827', 'taurochenodeoxycholate': 'HMDB0000949', 'taurocholate': 'HMDB0000036', 'taurodeoxycho ...
# 138 metabolites in this dataset are mapped to a hmdb id

# %%
# How many metabolites_hmdb are in the interactions file?
metabolites_in_interactions = interactions['HMDB'].isin(metabolites_hmdb)
print(f'{metabolites_in_interactions.sum()} metabolites in the interactions file are in the dataset')
# how many metabolites in the dataset are in the interactions file?
metabolites_in_dataset = pd.Series(list(metabolites_hmdb)).isin(interactions['HMDB'])
print(f'{metabolites_in_dataset.sum()} metabolites in the dataset are in the interactions file')
# Out:
# 137 metabolites in the interactions file are in the dataset
# 138 metabolites in the dataset are in the interactions file

# %%
interactions
# Out:
#                               Name         HMDB    ChEBI    KEGG   PubChem  \
# 0                1-Methylhistidine  HMDB0000001  50599.0  C01152   92105.0
# 1               1,3-Diaminopropane  HMDB0000002  15725.0  C00986     428.0
# 2               2-Ketobutyric acid  HMDB0000005  30831.0  C00109      58.0
# 3            2-Hydroxybutyric acid  HMDB0000008  50613.0  C05984  440864.0
# 4                 2-Methoxyestrone  HMDB0000010   1189.0  C05299  440624.0
# ...                            ...          ...      ...     ...       ...
# 217915         Nordeoxycholic acid  HMDB0304947      NaN     NaN  314374.0
# 217916  3-Oxo-5beta-cholanoic acid  HMDB0304950      NaN     NaN  543448.0
# 217917        Glycerol 1-myristate  HMDB0304951  75562.0     NaN   79050.0
# 217918       O-Phenolsulfonic acid  HMDB0304953  71049.0     NaN   11867.0
# 217919                   d-Fucitol  HMDB0304954      NaN     NaN  445724.0
#
#                                                IUPAC_Name  \
# 0       (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)prop...
# 1                                     propane-1,3-diamine
# 2                                      2-oxobutanoic acid
# 3                             (2S)-2-hydroxybutanoic acid
# 4       (1S,10R,11S,15S)-5-hydroxy-4-methoxy-15-methyl...
# ...                                                   ...
# 217915  3-{5,16-dihydroxy-2,15-dimethyltetracyclo[8.7....
# 217916  4-{2,15-dimethyl-5-oxotetracyclo[8.7.0.0^{2,7}...
# 217917                 2,3-dihydroxypropyl tetradecanoate
# 217918                   2-hydroxybenzene-1-sulfonic acid
# 217919              (2R,3S,4R,5S)-hexane-1,2,3,4,5-pentol
#
#                                                    SMILES  \
# 0                             CN1C=NC(C[C@H](N)C(O)=O)=C1
# 1                                                   NCCCN
# 2                                           CCC(=O)C(O)=O
# 3                                        CC[C@H](O)C(O)=O
# 4       [H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[...
# ...                                                   ...
# 217915     CC(CC(O)=O)C1CCC2C3CCC4CC(O)CCC4(C)C3CC(O)C12C
# 217916      CC(CCC(O)=O)C1CCC2C3CCC4CC(=O)CCC4(C)C3CCC12C
# 217917                         CCCCCCCCCCCCCC(=O)OCC(O)CO
# 217918                             OC1=CC=CC=C1S(O)(=O)=O
# 217919  [H][C@@](C)(O)[C@@]([H])(O)[C@@]([H])(O)[C@]([...
#
#                            InChIKey PDB_ID                          Kingdom  \
# 0       BRMWTNUJHUMWMS-LURJTMIESA-N    NaN    Organic acids and derivatives
# 1       XFNJVJPLKCPIBV-UHFFFAOYSA-N    NaN       Organic nitrogen compounds
# 2       TYEYBOSBBBHJIV-UHFFFAOYSA-N    NaN    Organic acids and derivatives
# 3       AFENDNXGAFYKQO-VKHMYHEASA-N    NaN    Organic acids and derivatives
# 4       WHEUWNKSCXYKBU-QPWUGHHJSA-N    NaN  Lipids and lipid-like molecules
# ...                             ...    ...                              ...
# 217915  PLRQOCVIINWCFA-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217916  KIQFUORWRVZTHT-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217917  DCBSHORRWZKAKO-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217918  IULJSGIJJZZUMF-UHFFFAOYSA-N    NaN                       Benzenoids
# 217919  SKCKOFZKJLZSFA-KCDKBNATSA-N    NaN         Organic oxygen compounds
#
#         ... IntAct                                          UniProtKB chEMBL  \
# 0       ...   none                                               none   none
# 1       ...   none              DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS   none
# 2       ...   none  RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...   none
# 3       ...   none                                               none   none
# 4       ...   none     COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT   none
# ...     ...    ...                                                ...    ...
# 217915  ...   none                                               none   none
# 217916  ...   none                       DHRS4|SDR25C2|UNQ851/PRO1800   none
# 217917  ...   none  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...   none
# 217918  ...   none                                               none   none
# 217919  ...   none                                               none   none
#
#           LINCS STITCH BioGRID  \
# 0           NaN    NaN   ACTA1
# 1           NaN    NaN     NaN
# 2           NaN    NaN     NaN
# 3           NaN    NaN     NaN
# 4       HSD17B1    NaN     NaN
# ...         ...    ...     ...
# 217915      NaN    NaN     NaN
# 217916      NaN    NaN     NaN
# 217917      NaN    NaN     NaN
# 217918      NaN    NaN     NaN
# 217919      NaN    NaN     NaN
#
#                                          Human1_GEM_dist1  \
# 0                                                     NaN
# 1             AOC1|AOC2|AOC3|DHPS|SLC22A1|SLC22A2|SLC22A3
# 2       BCKDHA|BCKDHB|CTH|GPT|LDHAL6A|LDHAL6B|LDHB|LDH...
# 3                                                     NaN
# 4                                       ABCB1|COMT|LRTOMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                          Human1_GEM_dist2  \
# 0                                                     NaN
# 1       AADAC|AASDH|ABHD12|ABHD6|ACAA1|ACAA2|ACE|ACE2|...
# 2       AADAC|AADAT|ABAT|ABHD12|ABHD6|ACE|ACE2|ACHE|AC...
# 3                                                     NaN
# 4       AADAC|ABCB1|ABHD12|ABHD6|ACE|ACE2|ACHE|ACP2|AC...
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                               MetalinksDB  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4                                       UGT1A8|ABCB1|COMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                 All_database_interactions
# 0                                                   ACTA1
# 1       DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS|AOC1|AOC...
# 2       RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4       COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT...
# ...                                                   ...
# 217915                                                NaN
# 217916                       DHRS4|SDR25C2|UNQ851/PRO1800
# 217917  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...
# 217918                                                NaN
# 217919                                                NaN
#
# [217920 rows x 22 columns]

# %%
with open('./ModuleViewer_files/metabolite_LemonIteKG_interactions.mvf', 'w') as handle:
    # Write header lines
    handle.write('::TYPE=LemonIte_KG\n')
    handle.write('::TITLE:LemonIte_KG\n')
    handle.write('::OBJECT=GENES\n')
    handle.write('::COLOR=YELLOW\n')

    # Loop over every module, and for every metabolite in the module, check if it is has interactions with genes in the module
    for module in module2mets.keys():
        module_genes = module2genes[module]
        module_mets = module2mets[module]
        
        for met in module_mets:
            met_hmdb = metabolite_mapping.get(met)
            if met_hmdb is None:
                #print(f'{met} not found in metabolite_mapping')
                continue
            met_interactions = interactions[interactions['HMDB'] == met_hmdb]
            if met_interactions.empty:
                print(f'{met} ({met_hmdb}) has no interactions')
                continue
            #print(met)
            met_genes = met_interactions['All_database_interactions'].values[0].split('|') if not pd.isna(met_interactions['All_database_interactions'].values[0]) else []
            #print(met_genes)
            #print(module_genes)
            
            shared_genes = set(module_genes).intersection(set(met_genes))
            print(f'{met} ({met_hmdb}) has {len(shared_genes)} interactions with genes in module {module}')
            #print(shared_genes)
            #print(module, metabolite, overlap)\
            if len(shared_genes) > 0:
                handle.write(str(int(module)) + '\t' + '|'.join(shared_genes) + '\t' + str(met) + '\n')
# Out:
# putrescine (HMDB0001414) has 2 interactions with genes in module 1
# adrenate (HMDB0002226) has 0 interactions with genes in module 10
# cadaverine (HMDB0002322) has 0 interactions with genes in module 11
# gabapentin (HMDB0005015) has 0 interactions with genes in module 11
# sphingosine (HMDB0000252) has 0 interactions with genes in module 11
# caproate (HMDB0000535) has 0 interactions with genes in module 12
# agmatine (HMDB0001432) has 1 interactions with genes in module 13
# hexadecanedioate (HMDB0304377) has 1 interactions with genes in module 13
# gabapentin (HMDB0005015) has 0 interactions with genes in module 13
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 14
# adrenate (HMDB0002226) has 4 interactions with genes in module 15
# carnosol (HMDB0002121) has 0 interactions with genes in module 17
# putrescine (HMDB0001414) has 0 interactions with genes in module 17
# serotonin (HMDB0000259) has 4 interactions with genes in module 18
# gabapentin (HMDB0005015) has 0 interactions with genes in module 19
# metronidazole (HMDB0015052) has 0 interactions with genes in module 19
# hippurate (HMDB0000714) has 0 interactions with genes in module 19
# theophylline (HMDB0001889) has 0 interactions with genes in module 19
# choline (HMDB0000097) has 0 interactions with genes in module 19
# glycine (HMDB0000123) has 17 interactions with genes in module 2
# adrenate (HMDB0002226) has 5 interactions with genes in module 20
# butyrobetaine (HMDB0001161) has 3 interactions with genes in module 22
# linoleate (HMDB0000673) has 1 interactions with genes in module 22
# anserine (HMDB0000194) has 0 interactions with genes in module 22
# crustecdysone (HMDB0030180) has 0 interactions with genes in module 23
# salicylate (HMDB0000840) has 0 interactions with genes in module 23
# piperine (HMDB0029377) has 0 interactions with genes in module 24
# metformin (HMDB0001921) has 0 interactions with genes in module 24
# trigonelline (HMDB0000875) has 0 interactions with genes in module 24
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 26
# carboxyibuprofen (HMDB0060564) has 0 interactions with genes in module 27
# agmatine (HMDB0001432) has 2 interactions with genes in module 28
# spermidine (HMDB0001257) has 3 interactions with genes in module 28
# trigonelline (HMDB0000875) has 0 interactions with genes in module 28
# serotonin (HMDB0000259) has 2 interactions with genes in module 29
# quinine (HMDB0014611) has 0 interactions with genes in module 29
# salicylate (HMDB0000840) has 0 interactions with genes in module 29
# arachidate (HMDB0002212) has 3 interactions with genes in module 3
# oleanate (HMDB0002364) has 0 interactions with genes in module 3
# glycoursodeoxycholate (HMDB0000708) has 1 interactions with genes in module 3
# ectoine (HMDB0240650) has 0 interactions with genes in module 30
# metronidazole (HMDB0015052) has 0 interactions with genes in module 30
# phytanate (HMDB0000801) has 0 interactions with genes in module 31
# carnitine (HMDB0000062) has 0 interactions with genes in module 32
# dodecanoate (HMDB0000638) has 0 interactions with genes in module 32
# myristate (HMDB0000806) has 0 interactions with genes in module 32
# hydroxycotinine (HMDB0001390) has 0 interactions with genes in module 32
# eicosanedioate (HMDB0242141) has 0 interactions with genes in module 33
# pentadecanoate (HMDB0000826) has 1 interactions with genes in module 34
# anserine (HMDB0000194) has 0 interactions with genes in module 35
# serotonin (HMDB0000259) has 2 interactions with genes in module 35
# hexadecanedioate (HMDB0304377) has 0 interactions with genes in module 36
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 37
# cadaverine (HMDB0002322) has 0 interactions with genes in module 37
# biliverdin (HMDB0001008) has 2 interactions with genes in module 38
# serotonin (HMDB0000259) has 2 interactions with genes in module 4
# choline (HMDB0000097) has 5 interactions with genes in module 40
# gabapentin (HMDB0005015) has 1 interactions with genes in module 40
# pyridoxine (HMDB0000239) has 3 interactions with genes in module 40
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 40
# gabapentin (HMDB0005015) has 0 interactions with genes in module 41
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 41
# hydrocinnamate (HMDB0000764) has 0 interactions with genes in module 41
# adrenate (HMDB0002226) has 0 interactions with genes in module 42
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 42
# deoxycholate (HMDB0000626) has 1 interactions with genes in module 43
# adenosine (HMDB0000050) has 0 interactions with genes in module 43
# eicosadienoate (HMDB0005060) has 1 interactions with genes in module 43
# cadaverine (HMDB0002322) has 0 interactions with genes in module 43
# docosapentaenoate (HMDB0001976) has 0 interactions with genes in module 44
# taurine (HMDB0000251) has 0 interactions with genes in module 44
# eicosapentaenoate (HMDB0001999) has 0 interactions with genes in module 44
# adrenate (HMDB0002226) has 0 interactions with genes in module 44
# trigonelline (HMDB0000875) has 0 interactions with genes in module 45
# hydroxycotinine (HMDB0001390) has 0 interactions with genes in module 45
# ornithine (HMDB0000214) has 4 interactions with genes in module 45
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 45
# tetradecanedioate (HMDB0000872) has 0 interactions with genes in module 46
# crustecdysone (HMDB0030180) has 0 interactions with genes in module 46
# metformin (HMDB0001921) has 0 interactions with genes in module 49
# serotonin (HMDB0000259) has 4 interactions with genes in module 5
# cadaverine (HMDB0002322) has 0 interactions with genes in module 5
# hydroxycotinine (HMDB0001390) has 0 interactions with genes in module 50
# myristoleate (HMDB0002000) has 0 interactions with genes in module 51
# lithocholate (HMDB0000717) has 0 interactions with genes in module 51
# quinine (HMDB0014611) has 0 interactions with genes in module 52
# putrescine (HMDB0001414) has 1 interactions with genes in module 52
# metformin (HMDB0001921) has 0 interactions with genes in module 52
# spermidine (HMDB0001257) has 1 interactions with genes in module 52
# glycine (HMDB0000123) has 3 interactions with genes in module 53
# acetaminophen (HMDB0001859) has 3 interactions with genes in module 53
# taurolithocholate (HMDB0000722) has 0 interactions with genes in module 54
# sphinganine (HMDB0000269) has 0 interactions with genes in module 54
# deoxycholate (HMDB0000626) has 4 interactions with genes in module 55
# carboxyibuprofen (HMDB0060564) has 0 interactions with genes in module 56
# taurolithocholate (HMDB0000722) has 1 interactions with genes in module 57
# pterin (HMDB0000802) has 0 interactions with genes in module 57
# homocitrulline (HMDB0000679) has 0 interactions with genes in module 58
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 59
# adrenate (HMDB0002226) has 0 interactions with genes in module 59
# urobilin (HMDB0004160) has 0 interactions with genes in module 59
# cholate (HMDB0000619) has 2 interactions with genes in module 6
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 6
# oxypurinol (HMDB0000786) has 0 interactions with genes in module 6
# gabapentin (HMDB0005015) has 0 interactions with genes in module 6
# putrescine (HMDB0001414) has 0 interactions with genes in module 6
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 6
# hydroxycotinine (HMDB0001390) has 0 interactions with genes in module 60
# metronidazole (HMDB0015052) has 0 interactions with genes in module 60
# sebacate (HMDB0000792) has 0 interactions with genes in module 61
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 61
# gabapentin (HMDB0005015) has 0 interactions with genes in module 61
# pyridoxine (HMDB0000239) has 0 interactions with genes in module 62
# deoxycholate (HMDB0000626) has 5 interactions with genes in module 63
# histidinol (HMDB0253185) has 0 interactions with genes in module 63
# metronidazole (HMDB0015052) has 0 interactions with genes in module 63
# eicosanedioate (HMDB0242141) has 0 interactions with genes in module 64
# cholesterol (HMDB0000067) has 0 interactions with genes in module 64
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 65
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 66
# theophylline (HMDB0001889) has 0 interactions with genes in module 66
# agmatine (HMDB0001432) has 0 interactions with genes in module 67
# hydroxycotinine (HMDB0001390) has 0 interactions with genes in module 67
# salicylate (HMDB0000840) has 0 interactions with genes in module 67
# arginine (HMDB0000517) has 0 interactions with genes in module 67
# serotonin (HMDB0000259) has 0 interactions with genes in module 68
# carboxyibuprofen (HMDB0060564) has 0 interactions with genes in module 69
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 72
# hydrocinnamate (HMDB0000764) has 0 interactions with genes in module 72
# gabapentin (HMDB0005015) has 0 interactions with genes in module 72
# metformin (HMDB0001921) has 0 interactions with genes in module 72
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 73
# adrenate (HMDB0002226) has 1 interactions with genes in module 73
# hippurate (HMDB0000714) has 2 interactions with genes in module 74
# dodecanoate (HMDB0000638) has 1 interactions with genes in module 74
# myristoleate (HMDB0002000) has 0 interactions with genes in module 74
# sphinganine (HMDB0000269) has 1 interactions with genes in module 75
# choline (HMDB0000097) has 1 interactions with genes in module 76
# hydroxyproline (HMDB0000725) has 1 interactions with genes in module 76
# gabapentin (HMDB0005015) has 0 interactions with genes in module 76
# urobilin (HMDB0004160) has 0 interactions with genes in module 77
# ornithine (HMDB0000214) has 1 interactions with genes in module 77
# citrulline (HMDB0000904) has 1 interactions with genes in module 78
# putrescine (HMDB0001414) has 0 interactions with genes in module 79
# adrenate (HMDB0002226) has 0 interactions with genes in module 79
# niacinamide (HMDB0001406) has 0 interactions with genes in module 79
# eicosanedioate (HMDB0242141) has 0 interactions with genes in module 8
# acesulfame (HMDB0033585) has 0 interactions with genes in module 8
# masilinate (HMDB0002392) has 0 interactions with genes in module 80
# lithocholate (HMDB0000717) has 0 interactions with genes in module 80
# caffeine (HMDB0001847) has 0 interactions with genes in module 80
# eicosanedioate (HMDB0242141) has 0 interactions with genes in module 82
# putrescine (HMDB0001414) has 0 interactions with genes in module 82
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 83
# putrescine (HMDB0001414) has 0 interactions with genes in module 84
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 84
# agmatine (HMDB0001432) has 0 interactions with genes in module 84
# gabapentin (HMDB0005015) has 0 interactions with genes in module 85
# lithocholate (HMDB0000717) has 0 interactions with genes in module 85
# taurine (HMDB0000251) has 0 interactions with genes in module 85
# serotonin (HMDB0000259) has 2 interactions with genes in module 86
# biliverdin (HMDB0001008) has 2 interactions with genes in module 87
# adrenate (HMDB0002226) has 1 interactions with genes in module 87
# eicosatrienoate (HMDB0002925) has 0 interactions with genes in module 87
# eicosadienoate (HMDB0005060) has 0 interactions with genes in module 87
# taurolithocholate (HMDB0000722) has 2 interactions with genes in module 87
# glycine (HMDB0000123) has 2 interactions with genes in module 88
# hexadecanedioate (HMDB0304377) has 1 interactions with genes in module 88
# metformin (HMDB0001921) has 0 interactions with genes in module 89
# dodecanedioate (HMDB0000623) has 0 interactions with genes in module 89
# hippurate (HMDB0000714) has 0 interactions with genes in module 89
# acesulfame (HMDB0033585) has 0 interactions with genes in module 89
# putrescine (HMDB0001414) has 2 interactions with genes in module 9
# betaine (HMDB0000043) has 0 interactions with genes in module 90
# choline (HMDB0000097) has 2 interactions with genes in module 90
# undecanedionate (HMDB0000888) has 0 interactions with genes in module 91
# adrenate (HMDB0002226) has 0 interactions with genes in module 91
# acesulfame (HMDB0033585) has 0 interactions with genes in module 91
# adrenate (HMDB0002226) has 0 interactions with genes in module 92
# quinine (HMDB0014611) has 0 interactions with genes in module 93
# quinine (HMDB0014611) has 0 interactions with genes in module 94
# porphobilinogen (HMDB0000245) has 1 interactions with genes in module 94
# serine (HMDB0000187) has 0 interactions with genes in module 96

# %% [markdown]
# # Create PPI interactions mvf for ModuleViewer

# %%
# Load PKN to extract PPI interactions
pkn = pd.read_csv(PKNnetwork_file, sep='\t')
print(f"PKN loaded: {pkn.shape}")
print(pkn.head())

# Filter for protein-protein interactions (gene-gene interactions)
# Assuming the PKN has columns like 'source', 'target', and possibly 'interaction_type'
# Adjust column names based on actual PKN structure
print("\nPKN columns:", pkn.columns.tolist())
# Out:
# PKN loaded: (2558081, 4)
#      Node1    Node2  Source Type
# 0  CYP26B1  ALDH1A2  STRING  PPI
# 1  CYP26B1  ALDH1A3  STRING  PPI
# 2  CYP26B1  ALDH1A1  STRING  PPI
# 3  CYP26B1   CRABP1  STRING  PPI
# 4  CYP26B1   CYP2B6  STRING  PPI
#
# PKN columns: ['Node1', 'Node2', 'Source', 'Type']

# %%
# Create PPI MVF file (optimized version)
# This file will contain protein-protein interactions between genes within each module

# Pre-process: Get all genes across all modules
all_module_genes = set()
for genes_list in module2genes.values():
    all_module_genes.update(genes_list)

print(f"Total unique genes across all modules: {len(all_module_genes)}")

# Filter PKN to only include genes that are in modules (both nodes must be in module genes)
pkn_filtered = pkn[
    (pkn['Node1'].isin(all_module_genes)) & 
    (pkn['Node2'].isin(all_module_genes))
].copy()

print(f"PKN rows before filtering: {len(pkn)}")
print(f"PKN rows after filtering: {len(pkn_filtered)}")

# Create a set of PPI pairs for O(1) lookup (store both directions)
ppi_set = set()
for _, row in pkn_filtered.iterrows():
    node1, node2 = row['Node1'], row['Node2']
    # Add both directions (undirected graph)
    ppi_set.add((node1, node2))
    ppi_set.add((node2, node1))

print(f"Total PPI pairs (bidirectional): {len(ppi_set)}")

# Now create the MVF file
with open('./ModuleViewer_files/PPI_interactions.mvf', 'w') as handle:
    # Write header lines
    handle.write('::TYPE=PPI\n')
    handle.write('::TITLE=Protein-Protein Interactions\n')
    handle.write('::OBJECT=GENE_PAIRS\n')
    handle.write('::COLOR=BLUE\n')
    
    ppi_count = 0
    
    # Loop over every module and find PPIs between genes in the module
    for module in module2genes.keys():
        module_genes = module2genes[module]
        module_ppis = []
        
        # Check all pairs of genes in the module for PPIs in the PKN
        for i, gene1 in enumerate(module_genes):
            for gene2 in module_genes[i+1:]:  # Only check each pair once
                # Fast O(1) lookup in set
                if (gene1, gene2) in ppi_set:
                    module_ppis.append(f"{gene1}|{gene2}")
                    ppi_count += 1
        
        # Write PPIs for this module
        for ppi in module_ppis:
            handle.write(f"{int(module)}\t{ppi}\n")
        
        if len(module_ppis) > 0:
            print(f"Module {module}: Found {len(module_ppis)} PPIs between module genes")
    
    print(f"\nTotal PPIs found across all modules: {ppi_count}")
    print(f"PPI file created: ./ModuleViewer_files/PPI_interactions.mvf")
# Out:
# Total unique genes across all modules: 3896
# PKN rows before filtering: 2558081
# PKN rows after filtering: 105415
# Total PPI pairs (bidirectional): 129283
# Module 0: Found 526 PPIs between module genes
# Module 1: Found 140 PPIs between module genes
# Module 2: Found 106 PPIs between module genes
# Module 3: Found 191 PPIs between module genes
# Module 4: Found 607 PPIs between module genes
# Module 5: Found 15 PPIs between module genes
# Module 6: Found 21 PPIs between module genes
# Module 7: Found 532 PPIs between module genes
# Module 8: Found 52 PPIs between module genes
# Module 9: Found 168 PPIs between module genes
# Module 10: Found 110 PPIs between module genes
# Module 11: Found 12 PPIs between module genes
# Module 12: Found 93 PPIs between module genes
# Module 13: Found 114 PPIs between module genes
# Module 14: Found 75 PPIs between module genes
# Module 15: Found 142 PPIs between module genes
# Module 16: Found 14 PPIs between module genes
# Module 17: Found 52 PPIs between module genes
# Module 18: Found 15 PPIs between module genes
# Module 19: Found 7 PPIs between module genes
# Module 20: Found 156 PPIs between module genes
# Module 21: Found 76 PPIs between module genes
# Module 22: Found 4 PPIs between module genes
# Module 23: Found 116 PPIs between module genes
# Module 24: Found 11 PPIs between module genes
# Module 25: Found 8 PPIs between module genes
# Module 26: Found 5 PPIs between module genes
# Module 27: Found 17 PPIs between module genes
# Module 28: Found 8 PPIs between module genes
# Module 29: Found 7 PPIs between module genes
# Module 30: Found 3 PPIs between module genes
# Module 31: Found 9 PPIs between module genes
# Module 32: Found 3 PPIs between module genes
# Module 33: Found 2 PPIs between module genes
# Module 34: Found 16 PPIs between module genes
# Module 35: Found 5 PPIs between module genes
# Module 37: Found 2 PPIs between module genes
# Module 38: Found 8 PPIs between module genes
# Module 39: Found 3 PPIs between module genes
# Module 40: Found 19 PPIs between module genes
# Module 41: Found 1 PPIs between module genes
# Module 42: Found 4 PPIs between module genes
# Module 43: Found 8 PPIs between module genes
# Module 44: Found 5 PPIs between module genes
# Module 45: Found 2 PPIs between module genes
# Module 46: Found 13 PPIs between module genes
# Module 47: Found 2 PPIs between module genes
# Module 48: Found 4 PPIs between module genes
# Module 49: Found 16 PPIs between module genes
# Module 50: Found 3 PPIs between module genes
# Module 52: Found 6 PPIs between module genes
# Module 53: Found 5 PPIs between module genes
# Module 54: Found 11 PPIs between module genes
# Module 55: Found 45 PPIs between module genes
# Module 56: Found 2 PPIs between module genes
# Module 57: Found 1 PPIs between module genes
# Module 58: Found 48 PPIs between module genes
# Module 59: Found 2 PPIs between module genes
# Module 60: Found 4 PPIs between module genes
# Module 61: Found 3 PPIs between module genes
# Module 62: Found 9 PPIs between module genes
# Module 63: Found 9 PPIs between module genes
# Module 64: Found 3 PPIs between module genes
# Module 65: Found 10 PPIs between module genes
# Module 66: Found 2 PPIs between module genes
# Module 67: Found 3 PPIs between module genes
# Module 69: Found 16 PPIs between module genes
# Module 70: Found 3 PPIs between module genes
# Module 71: Found 4 PPIs between module genes
# Module 72: Found 1 PPIs between module genes
# Module 73: Found 2 PPIs between module genes
# Module 74: Found 5 PPIs between module genes
# Module 75: Found 24 PPIs between module genes
# Module 76: Found 3 PPIs between module genes
# Module 77: Found 1 PPIs between module genes
# Module 78: Found 4 PPIs between module genes
# Module 79: Found 1 PPIs between module genes
# Module 80: Found 13 PPIs between module genes
# Module 81: Found 9 PPIs between module genes
# Module 82: Found 1 PPIs between module genes
# Module 84: Found 1 PPIs between module genes
# Module 85: Found 1 PPIs between module genes
# Module 86: Found 1 PPIs between module genes
# Module 87: Found 1 PPIs between module genes
# Module 88: Found 2 PPIs between module genes
# Module 90: Found 4 PPIs between module genes
# Module 94: Found 2 PPIs between module genes
# Module 95: Found 1 PPIs between module genes
# Module 96: Found 1 PPIs between module genes
#
# Total PPIs found across all modules: 3792
# PPI file created: ./ModuleViewer_files/PPI_interactions.mvf

# %% [markdown]
# # Calculate PPI enrichment for modules
#
# Test whether modules have more PPIs than expected by chance using hypergeometric test

# %%
# Calculate PPI enrichment for each module using hypergeometric test

# Get all genes that are in any module
all_genes_in_modules = list(all_module_genes)
N_total_genes = len(all_genes_in_modules)

# Count total possible PPIs among genes in modules
total_possible_ppis = (N_total_genes * (N_total_genes - 1)) // 2

# Count total observed PPIs in the PKN among module genes
total_observed_ppis = len(ppi_set) // 2  # Divide by 2 because we stored both directions

print(f"Total genes in modules: {N_total_genes}")
print(f"Total possible gene pairs: {total_possible_ppis}")
print(f"Total PPIs in PKN among module genes: {total_observed_ppis}")
print(f"Overall PPI density: {total_observed_ppis / total_possible_ppis:.4f}")

# Calculate enrichment for each module
enrichment_results = []

for module in module2genes.keys():
    module_genes = module2genes[module]
    n_genes = len(module_genes)
    
    if n_genes < 2:
        continue  # Skip modules with less than 2 genes
    
    # Count PPIs in this module
    n_ppis_in_module = 0
    for i, gene1 in enumerate(module_genes):
        for gene2 in module_genes[i+1:]:
            if (gene1, gene2) in ppi_set:
                n_ppis_in_module += 1
    
    # Hypergeometric test:
    # Population size: N_total_genes
    # Number of success states in population: total_observed_ppis
    # Number of draws: number of possible pairs in module = n_genes * (n_genes - 1) / 2
    # Number of observed successes: n_ppis_in_module
    
    # For hypergeometric test with pairs, we need to think of it differently:
    # - Population: all possible gene pairs in all modules
    # - Success in population: gene pairs that have a PPI
    # - Sample: all possible pairs in this module
    # - Observed successes: PPIs in this module
    
    n_possible_pairs_in_module = (n_genes * (n_genes - 1)) // 2
    
    # Hypergeometric p-value (probability of seeing this many or more PPIs by chance)
    # Using survival function (1 - CDF) to get upper tail probability
    p_value = hypergeom.sf(
        n_ppis_in_module - 1,  # -1 because sf is P(X >= k), we want P(X > k-1) = P(X >= k)
        M=total_possible_ppis,  # Total possible pairs
        n=total_observed_ppis,  # Total pairs with PPIs
        N=n_possible_pairs_in_module  # Pairs in module
    )
    
    # Calculate expected number of PPIs
    expected_ppis = n_possible_pairs_in_module * (total_observed_ppis / total_possible_ppis)
    
    # Fold enrichment
    fold_enrichment = n_ppis_in_module / expected_ppis if expected_ppis > 0 else 0
    
    enrichment_results.append({
        'Module': module,
        'N_genes': n_genes,
        'N_PPIs_observed': n_ppis_in_module,
        'N_PPIs_expected': expected_ppis,
        'Fold_enrichment': fold_enrichment,
        'P_value': p_value,
        'PPI_density': n_ppis_in_module / n_possible_pairs_in_module if n_possible_pairs_in_module > 0 else 0
    })

# Convert to DataFrame
enrichment_df = pd.DataFrame(enrichment_results)

# Add FDR correction
from scipy.stats import false_discovery_control
enrichment_df['FDR'] = false_discovery_control(enrichment_df['P_value'].values, method='bh')

# Sort by p-value
enrichment_df = enrichment_df.sort_values('P_value')

print(f"\nPPI Enrichment Results (top 10 most enriched modules):")
print(enrichment_df.head(10).to_string())

# Save results
enrichment_df.to_csv('./ModuleViewer_files/PPI_enrichment_results.csv', index=False)
print(f"\nFull results saved to: ./ModuleViewer_files/PPI_enrichment_results.csv")

# Summary statistics
n_significant = (enrichment_df['FDR'] < 0.05).sum()
print(f"\nNumber of modules significantly enriched for PPIs (FDR < 0.05): {n_significant} / {len(enrichment_df)}")
print(f"Mean fold enrichment: {enrichment_df['Fold_enrichment'].mean():.2f}")
print(f"Median fold enrichment: {enrichment_df['Fold_enrichment'].median():.2f}")
# Out:
# Total genes in modules: 3896
# Total possible gene pairs: 7587460
# Total PPIs in PKN among module genes: 64641
# Overall PPI density: 0.0085
#
# PPI Enrichment Results (top 10 most enriched modules):
#    Module  N_genes  N_PPIs_observed  N_PPIs_expected  Fold_enrichment        P_value  PPI_density            FDR
# 0       0      100              526        42.171287        12.472942   0.000000e+00     0.106263   0.000000e+00
# 4       4      151              607        96.482792         6.291277  1.476276e-271     0.053598  7.159937e-270
# 7       7      135              532        77.058442         6.903851  4.967733e-257     0.058817  1.606234e-255
# 3       3       64              191        17.175215        11.120676  5.187090e-130     0.094742  1.257869e-128
# 10     10       42              110         7.335248        14.996085   1.080898e-89     0.127758   2.096943e-88
# 9       9       74              168        23.011039         7.300844   4.741893e-86     0.062199   7.666060e-85
# 58     58       13               48         0.664517        72.232889   1.201107e-78     0.615385   1.664392e-77
# 13     13       53              114        11.739805         9.710553   5.739903e-72     0.082729   6.959632e-71
# 1       1       71              140        21.170838         6.612870   1.113701e-66     0.056338   1.200322e-65
# 12     12       46               93         8.817633        10.547049   3.299210e-62     0.089855   3.200234e-61
#
# Full results saved to: ./ModuleViewer_files/PPI_enrichment_results.csv
#
# Number of modules significantly enriched for PPIs (FDR < 0.05): 33 / 97
# Mean fold enrichment: 3.62
# Median fold enrichment: 1.39

# %%
# Visualize PPI enrichment results

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Volcano plot: Fold enrichment vs -log10(p-value)
ax = axes[0, 0]
enrichment_df['neg_log10_pval'] = -np.log10(enrichment_df['P_value'] + 1e-300)  # Add small value to avoid log(0)
scatter = ax.scatter(enrichment_df['Fold_enrichment'], 
                    enrichment_df['neg_log10_pval'],
                    c=enrichment_df['FDR'] < 0.05, 
                    cmap='RdYlBu_r',
                    alpha=0.6,
                    s=50)
ax.axhline(-np.log10(0.05), color='red', linestyle='--', alpha=0.5, label='P=0.05')
ax.axvline(1, color='gray', linestyle='--', alpha=0.5, label='No enrichment')
ax.set_xlabel('Fold Enrichment', fontsize=12)
ax.set_ylabel('-log10(P-value)', fontsize=12)
ax.set_title('PPI Enrichment Volcano Plot', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)

# 2. Distribution of fold enrichments
ax = axes[0, 1]
ax.hist(enrichment_df['Fold_enrichment'], bins=30, edgecolor='black', alpha=0.7)
ax.axvline(1, color='red', linestyle='--', linewidth=2, label='No enrichment')
ax.axvline(enrichment_df['Fold_enrichment'].median(), color='blue', linestyle='--', 
          linewidth=2, label=f'Median: {enrichment_df["Fold_enrichment"].median():.2f}')
ax.set_xlabel('Fold Enrichment', fontsize=12)
ax.set_ylabel('Number of Modules', fontsize=12)
ax.set_title('Distribution of Fold Enrichment', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)

# 3. Observed vs Expected PPIs
ax = axes[1, 0]
ax.scatter(enrichment_df['N_PPIs_expected'], enrichment_df['N_PPIs_observed'], 
          c=enrichment_df['FDR'] < 0.05, cmap='RdYlBu_r', alpha=0.6, s=50)
max_val = max(enrichment_df['N_PPIs_expected'].max(), enrichment_df['N_PPIs_observed'].max())
ax.plot([0, max_val], [0, max_val], 'k--', alpha=0.5, label='Expected')
ax.set_xlabel('Expected PPIs', fontsize=12)
ax.set_ylabel('Observed PPIs', fontsize=12)
ax.set_title('Observed vs Expected PPIs', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)

# 4. PPI density vs module size
ax = axes[1, 1]
scatter = ax.scatter(enrichment_df['N_genes'], enrichment_df['PPI_density'],
                    c=enrichment_df['FDR'] < 0.05, cmap='RdYlBu_r', alpha=0.6, s=50)
ax.axhline(total_observed_ppis / total_possible_ppis, color='red', linestyle='--', 
          alpha=0.5, label='Overall PPI density')
ax.set_xlabel('Module Size (# genes)', fontsize=12)
ax.set_ylabel('PPI Density', fontsize=12)
ax.set_title('PPI Density vs Module Size', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('./ModuleViewer_files/PPI_enrichment_analysis.png', dpi=300, bbox_inches='tight')
plt.savefig('./ModuleViewer_files/PPI_enrichment_analysis.pdf', dpi=300, bbox_inches='tight')
plt.show()

print("Saved enrichment visualization to ./ModuleViewer_files/PPI_enrichment_analysis.png/pdf")
# Out:
# Saved enrichment visualization to ./ModuleViewer_files/PPI_enrichment_analysis.png/pdf
