# %%
#####################################################################################################################################
##### This script evaluates the performance of the LemonIte network against PKN
##### This will be done in two different approaches:
#####       1. Classic evaluation metrics (accuracy, precision, recall, F1-score) of LemonIte network against the ground truth data
#####       2. Evaluation of average shortest paths for metabolite-gene pairs from LemonIte network in the PKN
#####################################################################################################################################

# %%
# import modules and set working directory
import os
import pandas as pd
import numpy as np
import networkx as nx
from multiprocessing import Pool
from scipy.stats import hypergeom
from adjustText import adjust_text
import matplotlib.pyplot as plt
import seaborn as sns

base_dir = '/home/borisvdm/Documents/PhD/Lemonite/Lloyd-Price_IBD/results/'
run_id = 'LemonTree'
percentile = 2
n_modules = 'selected_86'

workdir = base_dir + run_id
os.chdir(workdir)

dataset_file = workdir + f'/Preprocessing/LemonPreprocessed_complete.txt'
lemonnetwork_file = workdir + f'/Networks/LemonNetwork_percentile{percentile}_{n_modules}modules.txt'
PKNnetwork_file = '/home/borisvdm/Documents/PhD/Lemonite/PKN/LemonIte_PKN.tsv'
annotated_mets = '/home/borisvdm/Documents/PhD/gut_brain/IBD/Lloyd-Price2019/data/name_map.txt'# paste metabolite list in MetaboAnalyst id mapping tool and download result + manually look into annotations
#metabolite_interactions_file = workdir + f'/PKN/HMDB_metabolites_gene_interactions.tsv'


TF_regulator_file = workdir+'/ModuleViewer_files/Lovering.percentile'+str(percentile)+'_list.txt'
metabolite_regulator_file = workdir+'/ModuleViewer_files/Metabolite.percentile'+str(percentile)+'_list.txt'
#metabolite_random_regulator_file = workdir+'ModuleViewer_files/Metabolite.randomreg_list.txt'
clusterfile = workdir+'/Lemon_out/clusters_list.txt'
metabolite_interactions_file = '/home/borisvdm/Documents/PhD/Lemonite/PKN/HMDB_metabolites_gene_interactions.csv'

# %% [markdown]
# # Read predicted network and create some dictionaries to map modules to genes, regulators to genes, etc

# %%
lemonnetwork = pd.read_csv(lemonnetwork_file, sep='\t')
lemonnetwork
lemonnetwork_metabolites = lemonnetwork[lemonnetwork['Type'] == 'Metabolite-gene']
print(lemonnetwork_metabolites)
# create dict with metabolite-gene interactions
metabolites2genes = {}
for index, row in lemonnetwork_metabolites.iterrows():
    if row['Regulator'] not in metabolites2genes:
        metabolites2genes[row['Regulator']] = [row['Target']]
    else:
        metabolites2genes[row['Regulator']].append(row['Target'])

genes_in_dataset = lemonnetwork['Target'].unique()
print(f'There are {len(genes_in_dataset)} genes in the dataset')
# Out:
#                   Regulator    Target     Score  Lemon_module             Type
# 18170             C20_1_LPC    IL27RA  0.625853             0  Metabolite-gene
# 18171             C20_1_LPC     IL21R  0.625853             0  Metabolite-gene
# 18172             C20_1_LPC      CD28  0.625853             0  Metabolite-gene
# 18173             C20_1_LPC   PPP1R18  0.625853             0  Metabolite-gene
# 18174             C20_1_LPC     SASH3  0.625853             0  Metabolite-gene
# ...                     ...       ...       ...           ...              ...
# 41357  C36_4_PC_plasmalogen    HOXA11 -0.394289            95  Metabolite-gene
# 41358  C36_4_PC_plasmalogen   C8orf48 -0.394289            95  Metabolite-gene
# 41359  C36_4_PC_plasmalogen   SLC22A3 -0.394289            95  Metabolite-gene
# 41360  C36_4_PC_plasmalogen  ADAMTS14 -0.394289            95  Metabolite-gene
# 41361  C36_4_PC_plasmalogen     TRPC3 -0.394289            95  Metabolite-gene
#
# [23192 rows x 5 columns]
# There are 3543 genes in the dataset

# %%
# Funtion to create a dictionary with all regulators per module (start from the regulators.fold file created using LemonTree_downstream.py)
def get_regulators(regfile):
    regs = {}
    with open(regfile) as f:
        for line in f:
            module = line.split('\t')[0]
            regulators = line.rstrip().split('\t')[1].split('|')
            regs[module] = regulators
    return regs

module2TFs = get_regulators(TF_regulator_file)
module2mets = get_regulators(metabolite_regulator_file)
module2genes = get_regulators(clusterfile)
#module2mets_random = get_regulators(metabolite_random_regulator_file)

print('modules:', module2genes)
print('TFs:', module2TFs)
print('mets:', module2mets)
#print('mets_random:', module2mets_random)
# Out:
# modules: {'0': ['IL27RA', 'IL21R', 'CD28', 'PPP1R18', 'SASH3', 'HLA-DOB', 'CD3D', 'WDFY4', 'AGAP2', 'TIGIT', 'NCKAP1L', 'MAP4K1', 'SCIMP', 'LBH', 'NCF1', 'CD53', 'CD79A', 'PHACTR1', 'CD48', 'ITGAL', 'CYTIP', 'POU2F2', 'RASAL3', 'SPOCK2', 'ICOS', 'PTPN7', 'FGD2', 'TLR6', 'HLA-DOA', 'SP140', 'BTK', 'SLAMF6', 'LTA', 'CORO1A', 'IKZF1', 'ACAP1', 'IL16', 'AIM2', 'LCK', 'TRAF3IP3', 'PPP1R16B', 'FMNL3', 'DOK3', 'ARHGDIB', 'CD180', 'PCED1B', 'SNX20', 'WIPF1', 'P2RY10', 'CD52', 'PARVG', 'PYHIN1', 'GMFG', 'RAC2', 'RASGRP1', 'JAK3', 'ANKRD44', 'PRKCB', 'SH2D3C', 'DENND1C', 'TRAF1', 'LAT2', 'APBB1IP', 'NLRC3', 'CARD11', 'LCP1', 'WAS', 'RHOH', 'SUSD3', 'GRAP', 'ARHGAP25', 'TMEM156', 'FAM78A', 'PLCG2', 'P2RY8', 'PTPRC', 'SELL', 'FGD3', 'ARHGAP15', 'RUNX3', 'KLHL6', 'ADAM19', 'ZNF831', 'DOCK2', 'RFTN1', 'RASSF2', 'KMO', 'SH2D1A', 'LIMD2', 'MYO1G', 'FMNL1', 'NFATC1', 'ARHGAP30', 'ITK', 'CD5', 'TNFSF8', 'HCLS1', 'PIK3CD', 'ARHGAP9', 'CD6'], '1': ['ITGA5', 'ARHGEF15', 'RGCC', 'THSD1', 'LOXL2', 'PCDH17', 'IGFBP5', 'SNCAIP', 'TNC', 'RGS5', 'MEOX1', 'MGP', 'SORCS2', 'COL4A2', 'ANGPTL2', 'MCAM', 'C1R', 'ADAMTS6', 'GPR176', 'CSGALNACT1', 'MMP19', 'THY1', 'APLNR', 'CDH5', 'ROBO4', 'COL6A3', 'COL7A1', 'FEZ1', 'ECSCR', 'GJC1', 'FIBIN', 'CD34', 'CD93', 'COL4A1', 'HTRA3', 'RBPMS', 'OSMR', 'KDR', 'CTSK', 'CLEC14A', 'VWF', 'ARHGAP23', '
', 'CD40', 'ITGAX', 'MAPK11'], '4': ['SGCE', 'PDGFRA', 'EFEMP2', 'MXRA5', 'CNNM1', 'FLRT2', 'TMEM47', 'COL13A1', 'FIGN', 'ZNF536', 'COL6A2', 'MCC', 'BMP4', 'CDH6', 'NLGN2', 'ARHGAP28', 'GPC6', 'DSEL', 'TSHZ2', 'EML1', 'FOXF1', 'MAPK10', 'AMPH', 'FAM171B', 'SNAI2', 'LAMA4', 'NUDT11', 'DKK3', 'FBLN1', 'NOTCH3', 'COL3A1', 'FOXF2', 'VSTM4', 'DLC1', 'ECM1', 'FBXL7', 'GRID1', 'IGDCC4', 'ITGA8', 'DZIP1', 'COL4A5', 'STON1', 'COL12A1', 'LOX', 'FBN1', 'COL1A1', 'SULF1', 'C14orf132', 'CAV1', 'DPYSL3', 'PAMR1', 'AEBP1', 'CCDC80', 'GLI1', 'CD109', 'LRRC32', 'CNTNAP1', 'NXN', 'SPARCL1', 'ARHGAP6', 'FERMT2', 'MMP2', 'CALD1', 'DDR2', 'MAB21L2', 'CLMP', 'PCDH18', 'COL5A1', 'GLI2', 'TNXB', 'GLT8D2', 'EHD2', 'PCDH7', 'OLFML2A', 'MFAP4', 'MRC2', 'SGCD', 'BOC', 'PDGFRB', 'COL4A6', 'MAP1A', 'GDNF', 'FKBP10', 'ABCC9', 'SLC16A2', 'LUM', 'NR2F1', 'TUB', 'NEGR1', 'C1S', 'FR ...
# TFs: {'0': ['SP140'], '1': ['SKIL', 'SMAD3', 'ZNF532', 'ZNF98', 'NFE2L3', 'TSHZ2', 'ETV4', 'MKX'], '10': ['SP140', 'HSF5', 'EBF1', 'PRDM1'], '11': ['TCF7L1', 'SALL2', 'MEIS3', 'ZBTB47', 'SMAD4', 'ZNF587', 'CDC5L', 'NKX2-3'], '12': ['RFX6'], '13': ['JPH2'], '14': ['CSRNP3', 'ZNF536', 'HOXA11', 'ZNF280D', 'EPAS1'], '15': ['ZNF671', 'NFATC2', 'ZNF532', 'ZNF512B', 'SP140', 'NFE2L2', 'RUNX2', 'RFX5', 'MKX'], '16': ['ZNF362', 'ZNF704', 'CEBPG', 'TP53', 'RFX6', 'RARA', 'NEUROG3', 'ZNF384', 'ZNF613'], '17': ['ZNF521', 'TGIF1', 'SKIL', 'RARA', 'SP3', 'ZNF24'], '18': ['OSR1', 'ZFHX4', 'TCF21'], '19': ['SMAD3', 'PBX3', 'ZBTB47', 'ZNF521', 'GATA4', 'FOSB', 'TEAD4', 'RUNX2'], '2': ['ETV1', 'CREB3L2', 'POU2F1', 'SKIL', 'PRDM4'], '20': ['SPI1', 'NFATC3', 'SP140', 'NFKB2', 'ELF2'], '21': ['RFX6', 'HOXD12', 'HOXD11', 'EVX2'], '22': ['TWIST1', 'CREBZF', 'MYRF', 'AEBP1'], '23': ['STAT3', 'ERF', 'ZFHX3', 'ZNF704'], '24': ['EBF4', 'TCF7L1', 'GLIS2', 'NKX2-3', 'ZNF853', 'MEIS3', 'SMAD4'], '25': ['CEBPB', 'STAT3', 'HAND2', 'STAT5B',
osanedioate', 'C18_2_LPC', 'C18_1_LPC'], '34': ['C14_carnitine', 'C2_carnitine', 'C3_carnitine', 'pentadecanoate', 'C20_1_LPC', 'C10_carnitine'], '35': ['anserine', 'carnosol_isomer', 'C50_4_TAG', '13_cis_retinoic_acid', 'serotonin', 'N_acetylglutamine', 'C38_5_DAG_[M_NH4]_'], '36': ['hexadecanedioate', 'C22_5_CE_[M_NH4]_'], '37': ['eicosadienoate', '3_hydroxyoctanoate', 'C51_2_TAG', 'cadaverine', '3^_O_methyladenosine'], '38': ['C42_0_TAG_[M_NH4]_', 'trimethylamine_N_oxide', 'C50_1_TAG_[M_NH4]_', 'biliverdin', 'C18_0_MAG_[M_NH4]_', 'C9_carnitine'], '39': ['C20_1_LPC', 'C24_0_SM', 'C38_4_PC'], '4 ...

# %%
# How many unique metabolites in module2mets.values()?
module2mets_values = [item for sublist in module2mets.values() for item in sublist]
print(f'There are {len(set(module2mets_values))} unique metabolites in module2mets')
# Out:
# There are 212 unique metabolites in module2mets

# %% [markdown]
# # Subset metabolite-gene interactions file for metabolites that are in the dataset

# %%
interactions = pd.read_csv(metabolite_interactions_file, sep='\t')
interactions
# Out:
# /tmp/ipykernel_90662/3026841620.py:1: DtypeWarning: Columns (15,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactions = pd.read_csv(metabolite_interactions_file, sep='\t')
#                               Name         HMDB    ChEBI    KEGG   PubChem  \
# 0                1-Methylhistidine  HMDB0000001  50599.0  C01152   92105.0
# 1               1,3-Diaminopropane  HMDB0000002  15725.0  C00986     428.0
# 2               2-Ketobutyric acid  HMDB0000005  30831.0  C00109      58.0
# 3            2-Hydroxybutyric acid  HMDB0000008  50613.0  C05984  440864.0
# 4                 2-Methoxyestrone  HMDB0000010   1189.0  C05299  440624.0
# ...                            ...          ...      ...     ...       ...
# 217915         Nordeoxycholic acid  HMDB0304947      NaN     NaN  314374.0
# 217916  3-Oxo-5beta-cholanoic acid  HMDB0304950      NaN     NaN  543448.0
# 217917        Glycerol 1-myristate  HMDB0304951  75562.0     NaN   79050.0
# 217918       O-Phenolsulfonic acid  HMDB0304953  71049.0     NaN   11867.0
# 217919                   d-Fucitol  HMDB0304954      NaN     NaN  445724.0
#
#                                                IUPAC_Name  \
# 0       (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)prop...
# 1                                     propane-1,3-diamine
# 2                                      2-oxobutanoic acid
# 3                             (2S)-2-hydroxybutanoic acid
# 4       (1S,10R,11S,15S)-5-hydroxy-4-methoxy-15-methyl...
# ...                                                   ...
# 217915  3-{5,16-dihydroxy-2,15-dimethyltetracyclo[8.7....
# 217916  4-{2,15-dimethyl-5-oxotetracyclo[8.7.0.0^{2,7}...
# 217917                 2,3-dihydroxypropyl tetradecanoate
# 217918                   2-hydroxybenzene-1-sulfonic acid
# 217919              (2R,3S,4R,5S)-hexane-1,2,3,4,5-pentol
#
#                                                    SMILES  \
# 0                             CN1C=NC(C[C@H](N)C(O)=O)=C1
# 1                                                   NCCCN
# 2                                           CCC(=O)C(O)=O
# 3                                        CC[C@H](O)C(O)=O
# 4       [H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[...
# ...                                                   ...
# 217915     CC(CC(O)=O)C1CCC2C3CCC4CC(O)CCC4(C)C3CC(O)C12C
# 217916      CC(CCC(O)=O)C1CCC2C3CCC4CC(=O)CCC4(C)C3CCC12C
# 217917                         CCCCCCCCCCCCCC(=O)OCC(O)CO
# 217918                             OC1=CC=CC=C1S(O)(=O)=O
# 217919  [H][C@@](C)(O)[C@@]([H])(O)[C@@]([H])(O)[C@]([...
#
#                            InChIKey PDB_ID                          Kingdom  \
# 0       BRMWTNUJHUMWMS-LURJTMIESA-N    NaN    Organic acids and derivatives
# 1       XFNJVJPLKCPIBV-UHFFFAOYSA-N    NaN       Organic nitrogen compounds
# 2       TYEYBOSBBBHJIV-UHFFFAOYSA-N    NaN    Organic acids and derivatives
# 3       AFENDNXGAFYKQO-VKHMYHEASA-N    NaN    Organic acids and derivatives
# 4       WHEUWNKSCXYKBU-QPWUGHHJSA-N    NaN  Lipids and lipid-like molecules
# ...                             ...    ...                              ...
# 217915  PLRQOCVIINWCFA-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217916  KIQFUORWRVZTHT-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217917  DCBSHORRWZKAKO-UHFFFAOYSA-N    NaN  Lipids and lipid-like molecules
# 217918  IULJSGIJJZZUMF-UHFFFAOYSA-N    NaN                       Benzenoids
# 217919  SKCKOFZKJLZSFA-KCDKBNATSA-N    NaN         Organic oxygen compounds
#
#         ... IntAct                                          UniProtKB chEMBL  \
# 0       ...   none                                               none   none
# 1       ...   none              DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS   none
# 2       ...   none  RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...   none
# 3       ...   none                                               none   none
# 4       ...   none     COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT   none
# ...     ...    ...                                                ...    ...
# 217915  ...   none                                               none   none
# 217916  ...   none                       DHRS4|SDR25C2|UNQ851/PRO1800   none
# 217917  ...   none  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...   none
# 217918  ...   none                                               none   none
# 217919  ...   none                                               none   none
#
#           LINCS STITCH BioGRID  \
# 0           NaN    NaN   ACTA1
# 1           NaN    NaN     NaN
# 2           NaN    NaN     NaN
# 3           NaN    NaN     NaN
# 4       HSD17B1    NaN     NaN
# ...         ...    ...     ...
# 217915      NaN    NaN     NaN
# 217916      NaN    NaN     NaN
# 217917      NaN    NaN     NaN
# 217918      NaN    NaN     NaN
# 217919      NaN    NaN     NaN
#
#                                          Human1_GEM_dist1  \
# 0                                                     NaN
# 1             AOC1|AOC2|AOC3|DHPS|SLC22A1|SLC22A2|SLC22A3
# 2       BCKDHA|BCKDHB|CTH|GPT|LDHAL6A|LDHAL6B|LDHB|LDH...
# 3                                                     NaN
# 4                                       ABCB1|COMT|LRTOMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                          Human1_GEM_dist2  \
# 0                                                     NaN
# 1       AADAC|AASDH|ABHD12|ABHD6|ACAA1|ACAA2|ACE|ACE2|...
# 2       AADAC|AADAT|ABAT|ABHD12|ABHD6|ACE|ACE2|ACHE|AC...
# 3                                                     NaN
# 4       AADAC|ABCB1|ABHD12|ABHD6|ACE|ACE2|ACHE|ACP2|AC...
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                               MetalinksDB  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4                                       UGT1A8|ABCB1|COMT
# ...                                                   ...
# 217915                                                NaN
# 217916                                                NaN
# 217917                                                NaN
# 217918                                                NaN
# 217919                                                NaN
#
#                                 All_database_interactions
# 0                                                   ACTA1
# 1       DHPS|DS|DHPS|DHPS|DHPS|DHPS|DHPS|DHPS|AOC1|AOC...
# 2       RIDA|HRSP12|SDS|SDH|SDSL|GOT1|CTH|AGXT2|AGT2|A...
# 3       SLC16A6|LDHC|SLC16A3|LDHB|LDHAL6B|SLC16A7|SLC1...
# 4       COMT|UGT1A8|GNT1|UGT1|COMT|COMT|COMT|COMT|COMT...
# ...                                                   ...
# 217915                                                NaN
# 217916                       DHRS4|SDR25C2|UNQ851/PRO1800
# 217917  ENPP6|UNQ1889/PRO4334|EPHX2|ABHD6|MGLL|MOGAT1|...
# 217918                                                NaN
# 217919                                                NaN
#
# [217920 rows x 22 columns]

# %%
# contextualize metabolite-gene interactions to dataset
metabolite_mapping = pd.read_csv(annotated_mets, sep=',')
print(metabolite_mapping)
# Create a dictionary that maps Query to HMDB
metabolite_mapping = metabolite_mapping.set_index('Query')['HMDB'].dropna().to_dict()
print(metabolite_mapping)
metabolites_hmdb = metabolite_mapping.values()
print(f'{len(metabolites_hmdb)} metabolites in this dataset are mapped to a hmdb id')
# Out:
#                                           Query                  Match  \
# 0                               1_methylguanine                    NaN
# 1                             1_methylguanosine                    NaN
# 2                             1_methylhistamine                    NaN
# 3                          1_methylnicotinamide                    NaN
# 4                              21_deoxycortisol                    NaN
# ..                                          ...                    ...
# 465  taurohyodeoxycholate/tauroursodeoxycholate                    NaN
# 466                           taurolithocholate     Lithocholyltaurine
# 467                           tetradecanedioate  Tetradecanedioic acid
# 468                                theophylline           Theophylline
# 469                             undecanedionate     Undecanedioic acid
#
#             HMDB   PubChem    ChEBI    KEGG  METLIN  \
# 0            NaN       NaN      NaN     NaN     NaN
# 1            NaN       NaN      NaN     NaN     NaN
# 2            NaN       NaN      NaN     NaN     NaN
# 3            NaN       NaN      NaN     NaN     NaN
# 4            NaN       NaN      NaN     NaN     NaN
# ..           ...       ...      ...     ...     ...
# 465          NaN       NaN      NaN     NaN     NaN
# 466  HMDB0000722  439763.0  36259.0  C02592  5690.0
# 467  HMDB0000872   13185.0  76308.0  C11002  5833.0
# 468  HMDB0001889    2153.0  28177.0  C07130  1458.0
'valine': 'HMDB0000883', 'cholesterol': 'HMDB0000067', 'linoleoylethanolamide': 'HMDB0012252', 'sphingosine': 'HMDB0000252', 'acesulfame': 'HMDB0033585', 'adrenate': 'HMDB0002226', 'arachidate': 'HMDB0002212', 'arachidonate': 'HMDB0001043', 'azelate': 'HMDB0000784', 'caprate': 'HMDB0000511', 'caproate': 'HMDB0000535', 'carboxyibuprofen': 'HMDB0060564', 'carnosol': 'HMDB0002121', 'chenodeoxycholate': 'HMDB0000518', 'cholate': 'HMDB0000619', 'crustecdysone': 'HMDB0030180', 'deoxycholate': 'HMDB0000626', 'docosahexaenoate': 'HMDB0002183', 'docosapentaenoate': 'HMDB0001976', 'dodecanedioate': 'HMDB0000623', 'dodecanoate': 'HMDB0000638', 'eicosadienoate': 'HMDB0005060', 'eicosanedioate': 'HMDB0242141', 'eicosapentaenoate': 'HMDB0001999', 'eicosatrienoate': 'HMDB0002925', 'eicosenoate': 'HMDB0002231', 'furosemide': 'HMDB0001933', 'glycochenodeoxycholate': 'HMDB0000637', 'glycocholate': 'HMDB0000138', 'glycodeoxycholate': 'HMDB0000631', 'glycolithocholate': 'HMDB0000698', 'glycoursodeoxycholate': 'HMDB0000708', 'heptanoate': 'HMDB0304376', 'hexadecanedioate': 'HMDB0304377', 'hydrochlorothiazide': 'HMDB0001928', 'hydrocinnamate': 'HMDB0000764', 'indoleacetate': 'HMDB0000197', 'linoleate': 'HMDB0000673', 'lithocholate': 'HMDB0000717', 'mandelate': 'HMDB0000703', 'masilinate': 'HMDB0002392', 'myristate': 'HMDB0000806', 'myristoleate': 'HMDB0002000', 'nonadecanoate': 'HMDB0000772', 'oleanate': 'HMDB0002364', 'oleate': 'HMDB0000207', 'olmesartan': 'HMDB0014420', 'oxymetazoline': 'HMDB0015070', 'oxypurinol': 'HMDB0000786', 'palmitate': 'HMDB0000220', 'palmitoleate': 'HMDB0003229', 'palmitoylethanolamide': 'HMDB0002100', 'pentadecanoate': 'HMDB0000826', 'phenyllactate': 'HMDB0000563', 'phytanate': 'HMDB0000801', 'porphobilinogen': 'HMDB0000245', 'saccharin': 'HMDB0029723', 'salicylate': 'HMDB0000840', 'sebacate': 'HMDB0000792', 'stearate': 'HMDB0000827', 'taurochenodeoxycholate': 'HMDB0000949', 'taurocholate': 'HMDB0000036', 'taurodeoxycho ...
# 138 metabolites in this dataset are mapped to a hmdb id

# %%
# How many metabolites_hmdb are in the interactions file?
metabolites_in_interactions = interactions['HMDB'].isin(metabolites_hmdb)
print(f'{metabolites_in_interactions.sum()} metabolites in the interactions file are in the dataset')
# how many metabolites in the dataset are in the interactions file?
metabolites_in_dataset = pd.Series(list(metabolites_hmdb)).isin(interactions['HMDB'])
print(f'{metabolites_in_dataset.sum()} metabolites in the dataset are in the interactions file')
# Out:
# 137 metabolites in the interactions file are in the dataset
# 138 metabolites in the dataset are in the interactions file

# %% [markdown]
# # Plot shortest paths between metabolite regulators and module genes in the LemonIte PKN

# %%
# Read networks
PKN = pd.read_csv(PKNnetwork_file, sep='\t', header=0)
# split Node1 on '_' and keep the last part
PKN['Node1'] = PKN['Node1'].str.split('_').str[-1]
print(PKN)

lemonnetwork = pd.read_csv(lemonnetwork_file, sep='\t', header=0)
print(lemonnetwork)
# Extract nodes from both networks
lemonnetwork_nodes = list(set(lemonnetwork['Regulator'].tolist() + lemonnetwork['Target'].tolist()))
PKN_nodes = list(set(PKN['Node1'].tolist() + PKN['Node2'].tolist()))

# create name_to_hmdb mapping for metabolites
name_to_hmdb = pd.read_csv(annotated_mets, sep=',')
name_to_hmdb = name_to_hmdb.set_index('Query')['HMDB'].dropna().to_dict()
print(name_to_hmdb)
# Out:
#                Node1     Node2     Source             Type
# 0            CYP26B1   ALDH1A2     STRING              PPI
# 1            CYP26B1   ALDH1A3     STRING              PPI
# 2            CYP26B1   ALDH1A1     STRING              PPI
# 3            CYP26B1    CRABP1     STRING              PPI
# 4            CYP26B1    CYP2B6     STRING              PPI
# ...              ...       ...        ...              ...
# 2558076  HMDB0304951    MOGAT2  UniProtKB  metabolite-gene
# 2558077  HMDB0304951       DC5  UniProtKB  metabolite-gene
# 2558078  HMDB0304951   DGAT2L5  UniProtKB  metabolite-gene
# 2558079  HMDB0304951    ABHD12  UniProtKB  metabolite-gene
# 2558080  HMDB0304951  C20orf22  UniProtKB  metabolite-gene
#
# [2558081 rows x 4 columns]
#                   Regulator    Target     Score  Lemon_module             Type
# 0                     SP140    IL27RA  6.797341             0          TF-gene
# 1                     SP140     IL21R  6.797341             0          TF-gene
# 2                     SP140      CD28  6.797341             0          TF-gene
# 3                     SP140   PPP1R18  6.797341             0          TF-gene
# 4                     SP140     SASH3  6.797341             0          TF-gene
# ...                     ...       ...       ...           ...              ...
# 41357  C36_4_PC_plasmalogen    HOXA11 -0.394289            95  Metabolite-gene
# 41358  C36_4_PC_plasmalogen   C8orf48 -0.394289            95  Metabolite-gene
# 41359  C36_4_PC_plasmalogen   SLC22A3 -0.394289            95  Metabolite-gene
# 41360  C36_4_PC_plasmalogen  ADAMTS14 -0.394289            95  Metabolite-gene
# 41361  C36_4_PC_plasmalogen     TRPC3 -0.394289            95  Metabolite-gene
#
# [41362 rows x 5 columns]
# {'acetaminophen': 'HMDB0001859', 'acetylcholine': 'HMDB0000895', 'adenosine': 'HMDB0000050', 'agmatine': 'HMDB0001432', 'alanine': 'HMDB0000161', 'alanylalanine': 'HMDB0028680', 'alloisoleucine': 'HMDB0000172', 'anserine': 'HMDB0000194', 'arginine': 'HMDB0000517', 'aspartate': 'HMDB0000191', 'atenolol': 'HMDB0001924', 'betaine': 'HMDB0000043', 'bilirubin': 'HMDB0000054', 'biliverdin': 'HMDB0001008', 'biotin': 'HMDB0000030', 'butyrobetaine': 'HMDB0001161', 'cadaverine': 'HMDB0002322', 'caffeine': 'HMDB0001847', 'carnitine': 'HMDB0000062', 'choline': 'HMDB0000097', 'citrulline': 'HMDB0000904', 'cortisol': 'HMDB0000063', 'cotinine': 'HMDB0001046', 'creatine': 'HMDB0000064', 'creatinine': 'HMDB0000562', 'cytidine': 'HMDB0000089', 'c
'HMDB0000703', 'masilinate': 'HMDB0002392', 'myristate': 'HMDB0000806', 'myristoleate': 'HMDB0002000', 'nonadecanoate': 'HMDB0000772', 'oleanate': 'HMDB0002364', 'oleate': 'HMDB0000207', 'olmesartan': 'HMDB0014420', 'oxymetazoline': 'HMDB0015070', 'oxypurinol': 'HMDB0000786', 'palmitate': 'HMDB0000220', 'palmitoleate': 'HMDB0003229', 'palmitoylethanolamide': 'HMDB0002100', 'pentadecanoate': 'HMDB0000826', 'phenyllactate': 'HMDB0000563', 'phytanate': 'HMDB0000801', 'porphobilinogen': 'HMDB0000245', 'saccharin': 'HMDB0029723', 'salicylate': 'HMDB0000840', 'sebacate': 'HMDB0000792', 'stearate': 'HMDB0000827', 'taurochenodeoxycholate': 'HMDB0000949', 'taurocholate': 'HMDB0000036', 'taurodeoxycho ...

# %%
# Map metabolite names in 'Regulator' column to HMDB ids
lemonnetwork['Regulator'] = lemonnetwork['Regulator'].map(name_to_hmdb) # Only rows involving a metabolite as regulator will be mapped, other will be set to nan
# drop rows with nan values in 'Regulator' column
lemonnetwork = lemonnetwork.dropna(subset=['Regulator'])
print(lemonnetwork)
# Out:
#          Regulator    Target     Score  Lemon_module             Type
# 19241  HMDB0001414     ITGA5  0.907596             1  Metabolite-gene
# 19242  HMDB0001414  ARHGEF15  0.907596             1  Metabolite-gene
# 19243  HMDB0001414      RGCC  0.907596             1  Metabolite-gene
# 19244  HMDB0001414     THSD1  0.907596             1  Metabolite-gene
# 19245  HMDB0001414     LOXL2  0.907596             1  Metabolite-gene
# ...            ...       ...       ...           ...              ...
# 41328  HMDB0000245    SPOCK3 -0.493984            94  Metabolite-gene
# 41329  HMDB0000245      PURG -0.493984            94  Metabolite-gene
# 41330  HMDB0000245     PCDH9 -0.493984            94  Metabolite-gene
# 41331  HMDB0000245     MMP16 -0.493984            94  Metabolite-gene
# 41332  HMDB0000245     NTRK3 -0.493984            94  Metabolite-gene
#
# [5893 rows x 5 columns]

# %%
# remove nodes from lemonnetwork that are not in the PKN
lemonnetwork = lemonnetwork[lemonnetwork['Regulator'].isin(PKN_nodes) & lemonnetwork['Target'].isin(PKN_nodes)]
lemonnetwork
# how many Metabolite-gene interactions remain in lemonnetwork?
#lemonnetwork_metabolites = lemonnetwork[lemonnetwork['Type'] == 'Metabolite-gene']
print(f'The LemonIte network contains {lemonnetwork_metabolites.shape[0]} Metabolite-gene interactions')
# Out:
# The LemonIte network contains 23192 Metabolite-gene interactions

# %%
PKN.nx = nx.from_pandas_edgelist(PKN, 'Node1', 'Node2')
# How many nodes and edges does the PKN contain?
print(f'The PKN contains {PKN.nx.number_of_nodes()} nodes and {PKN.nx.number_of_edges()} edges')
lemonnetwork.nx = nx.from_pandas_edgelist(lemonnetwork, 'Regulator', 'Target')
# How many nodes and edges does the LemonIte network contain?
print(f'The LemonIte network contains {lemonnetwork.nx.number_of_nodes()} nodes and {lemonnetwork.nx.number_of_edges()} edges')
# Out:
# The PKN contains 41137 nodes and 1955213 edges
# The LemonIte network contains 2916 nodes and 5065 edges
# /tmp/ipykernel_90662/162738182.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   PKN.nx = nx.from_pandas_edgelist(PKN, 'Node1', 'Node2')
# /tmp/ipykernel_90662/162738182.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   lemonnetwork.nx = nx.from_pandas_edgelist(lemonnetwork, 'Regulator', 'Target')

# %% [markdown]
# # Plot some shortest paths and their neighborhoods

# %%
def create_edge_legend_by_category(ax, edge_styles, edge_info):
    """Create a legend showing edge categories present in the network"""
    from matplotlib.lines import Line2D
    from matplotlib.patches import FancyArrowPatch
    
    # Get unique categories in this network
    present_categories = set()
    for info in edge_info.values():
        present_categories.add(info.get('category', 'Unknown'))
    
    # Create legend elements for all categories in edge_styles
    legend_elements = []
    for category in sorted(edge_styles.keys()):
        style = edge_styles[category]
        
        if category == 'Metabolic_pathway':
            # For Metabolic_pathway, show a line with a dot marker at the end
            legend_elements.append(
                Line2D([0, 1], [0, 0], 
                      marker='o', markersize=6, markerfacecolor=style['color'],
                      markeredgecolor='black', markeredgewidth=0.5,
                      color=style['color'], linewidth=style['width'],
                      linestyle=style['style'], alpha=style['alpha'],
                      label=style['label'])
            )
        elif category == 'Causal':
            # Arrow marker for Causal - use FancyArrowPatch to match drawing
            legend_elements.append(
                FancyArrowPatch((0, 0), (1, 0),
                              arrowstyle='-|>',
                              mutation_scale=15,
                              color=style['color'],
                              linewidth=style['width'],
                              alpha=style['alpha'],
                              label=style['label'])
            )
        else:
            # Normal line for others (PPI, Ambiguous, Unknown)
            legend_elements.append(
                Line2D([0, 1], [0, 0], 
                      color=style['color'], 
                      linewidth=style['width'],
                      linestyle=style['style'],
                      alpha=style['alpha'],
                      label=style['label'])
            )
    
    # Add legend if there are elements
    if legend_elements:
        return legend_elements
    return []

# %%
########################################################################################################################################
# Helper functions for categorizing and styling edges based on interaction type and source
########################################################################################################################################

def get_edge_type_category(source, edge_type):
    """
    Categorize edge sources into interaction types based on the edge type (metabolite-gene or PPI)
    
    Parameters:
    -----------
    source : str
        The source database (e.g., 'LINCS', 'STRING', 'BioGRID')
    edge_type : str
        Type of edge - either 'metabolite-gene' or 'PPI'
    
    Returns:
    --------
    str : Interaction category
    """
    
    if edge_type == 'metabolite-gene':
        # Categorization for metabolite-gene interactions only
        causal_sources = ['LINCS', 'chEMBL']
        metabolic_sources = ['Human1_GEM_dist1', 'Human1_GEM_dist2']
        
        if source in causal_sources:
            return 'Causal'
        elif source in metabolic_sources:
            return 'Metabolic_pathway'
        else:
            return 'Ambiguous'
    
    elif edge_type == 'PPI':
        # All PPI interactions are simply categorized as PPI (shown as gray)
        return 'PPI'
    
    else:
        return 'PPI'


def get_edge_style_mapping():
    """
    Define visual styles for each interaction category
    Metabolite-gene interactions have 3 types (Causal, Metabolic_pathway, Ambiguous)
    PPI interactions are all shown as gray lines
    """
    return {
        # Metabolite-gene interaction styles - all dark grey, distinguished by markers
        'Causal': {
            'color': '#555555',  # Dark grey - causal relationships
            'style': 'solid',
            'width': 3.0,
            'alpha': 0.9,
            'label': 'Causal (LINCS/chEMBL)'
        },
        'Metabolic_pathway': {
            'color': '#555555',  # Dark grey - metabolic pathways
            'style': 'solid',
            'width': 2.5,
            'alpha': 0.85,
            'label': 'Metabolic pathway (GEM)'
        },
        'Ambiguous': {
            'color': '#555555',  # Dark grey - ambiguous
            'style': 'solid',
            'width': 2.0,
            'alpha': 0.7,
            'label': 'Ambiguous (other)'
        },
        
        # PPI interaction style (light grey)
        'PPI': {
            'color': '#A9A9A9',  # Darker light grey - protein-protein interactions
            'style': 'solid',
            'width': 1.5,
            'alpha': 0.5,
            'label': 'PPI'
        }
    }


def get_edge_source_and_type(PKN_df, node1, node2):
    """
    Get both the source database and the interaction type for an edge
    
    Returns:
    --------
    tuple : (source, edge_type, category)
    """
    # Check both directions (undirected graph)
    match = PKN_df[((PKN_df['Node1'] == node1) & (PKN_df['Node2'] == node2)) |
                   ((PKN_df['Node1'] == node2) & (PKN_df['Node2'] == node1))]
    
    if not match.empty:
        source = match.iloc[0]['Source']
        edge_type = match.iloc[0]['Type']
        category = get_edge_type_category(source, edge_type)
        return source, edge_type, category
    
    return 'unknown', 'unknown', 'PPI'


def create_edge_legend_by_category(ax, edge_styles, edge_info):
    """Create a legend showing edge categories present in the network"""
    from matplotlib.lines import Line2D
    from matplotlib.patches import FancyArrowPatch
    
    # Get unique categories in this network
    present_categories = set()
    for info in edge_info.values():
        present_categories.add(info.get('category', 'PPI'))
    
    # Create legend elements for all categories in edge_styles
    legend_elements = []
    for category in sorted(edge_styles.keys()):
        style = edge_styles[category]
        
        if category == 'Metabolic_pathway':
            # For Metabolic_pathway, show a line with a dot marker at the end
            legend_elements.append(
                Line2D([0, 1], [0, 0], 
                      marker='o', markersize=6, markerfacecolor=style['color'],
                      markeredgecolor='black', markeredgewidth=0.5,
                      color=style['color'], linewidth=style['width'],
                      linestyle=style['style'], alpha=style['alpha'],
                      label=style['label'])
            )
        elif category == 'Causal':
            # For Causal, show a line with an arrow marker
            legend_elements.append(
                Line2D([0, 1], [0, 0], 
                      marker='>', markersize=8, markerfacecolor=style['color'],
                      markeredgecolor='black', markeredgewidth=0.5,
                      color=style['color'], linewidth=style['width'],
                      linestyle=style['style'], alpha=style['alpha'],
                      label=style['label'])
            )
        else:
            # Normal line for others (PPI, Ambiguous)
            legend_elements.append(
                Line2D([0, 1], [0, 0], 
                      color=style['color'], 
                      linewidth=style['width'],
                      linestyle=style['style'],
                      alpha=style['alpha'],
                      label=style['label'])
            )
    
    # Add legend if there are elements
    if legend_elements:
        return legend_elements
    return []


def create_node_legend(ax, has_metabolites, has_tfs, has_targets, has_bridge):
    """Create a legend showing node colors present in the network"""
    from matplotlib.patches import Patch
    
    legend_elements = []
    
    if has_metabolites:
        legend_elements.append(Patch(facecolor='red', edgecolor='black', label='Metabolites'))
    if has_tfs:
        legend_elements.append(Patch(facecolor='lightgreen', edgecolor='black', label='TFs'))
    if has_targets:
        legend_elements.append(Patch(facecolor='orange', edgecolor='black', label='Targets'))
    if has_bridge:
        legend_elements.append(Patch(facecolor='lightgrey', edgecolor='black', label='Bridge'))
    
    # Return legend elements
    return legend_elements


def print_edge_statistics(edge_info):
    """Print statistics about edge types and categories"""
    from collections import Counter
    
    categories = [info.get('category', 'PPI') for info in edge_info.values()]
    types = [info.get('type', 'unknown') for info in edge_info.values()]
    sources = [info.get('source', 'unknown') for info in edge_info.values()]
    
    print("\n=== Edge Statistics ===")
    print("\nBy Category:")
    for cat, count in Counter(categories).most_common():
        print(f"  {cat}: {count}")
    
    print("\nBy Type:")
    for typ, count in Counter(types).most_common():
        print(f"  {typ}: {count}")
    
    print("\nBy Source:")
    for src, count in Counter(sources).most_common():
        print(f"  {src}: {count}")

# %%
def export_to_cytoscape_with_categories(graph, module, hmdb_to_name, TF_regulators, target_genes, edge_info, PKN_df):
    """Export network with edge category information for Cytoscape"""
    import os
    
    cytoscape_dir = "./Networks/cytoscape"
    os.makedirs(cytoscape_dir, exist_ok=True)
    
    # Export edges with full information
    edges_data = []
    for u, v in graph.edges():
        node1 = hmdb_to_name.get(u, u)
        node2 = hmdb_to_name.get(v, v)
        
        info = edge_info.get((u, v)) or edge_info.get((v, u), {})
        source = info.get('source', 'unknown')
        edge_type = info.get('type', 'unknown')
        category = info.get('category', 'PPI')
        
        edges_data.append({
            'Node1': node1,
            'Node2': node2,
            'Source': source,
            'Type': edge_type,
            'Category': category
        })
    
    edges_df = pd.DataFrame(edges_data)
    edges_file = f"{cytoscape_dir}/module_{module}_edges_categorized.tsv"
    edges_df.to_csv(edges_file, sep='\t', index=False)
    
    # Export node attributes
    attributes_data = []
    for node in graph.nodes():
        if node in hmdb_to_name:
            node_type = 'metabolite'
            label = hmdb_to_name[node]
        elif node in TF_regulators:
            node_type = 'TF'
            label = node
        elif node in target_genes:
            node_type = 'module_gene'
            label = node
        else:
            node_type = 'bridge_node'
            label = node
        
        attributes_data.append({
            'Node': label,
            'Label': label,
            'Type': node_type
        })
    
    attributes_df = pd.DataFrame(attributes_data)
    attributes_file = f"{cytoscape_dir}/module_{module}_attributes.tsv"
    attributes_df.to_csv(attributes_file, sep='\t', index=False)
    
    print(f"\nCytoscape files with categorized edges saved for module {module}:")
    print(f"  Edges: {edges_file}")
    print(f"  Attributes: {attributes_file}")

# %%
def get_edge_style_mapping():
    """
    Define visual styles for each interaction category
    Metabolite-gene interactions have 3 types (Causal, Metabolic_pathway, Ambiguous)
    PPI interactions are all shown as gray lines
    """
    return {
        # Metabolite-gene interaction styles - all dark grey, distinguished by markers
        'Causal': {
            'color': '#555555',  # Dark grey - causal relationships
            'style': 'solid',
            'width': 3.0,
            'alpha': 0.9,
            'label': 'Causal (LINCS/chEMBL)'
        },
        'Metabolic_pathway': {
            'color': '#555555',  # Dark grey - metabolic pathways
            'style': 'solid',
            'width': 2.5,
            'alpha': 0.85,
            'label': 'Metabolic pathway (GEM)'
        },
        'Ambiguous': {
            'color': '#555555',  # Dark grey - ambiguous
            'style': 'solid',
            'width': 2.0,
            'alpha': 0.7,
            'label': 'Ambiguous (other)'
        },
        
        # PPI interaction style (light grey)
        'PPI': {
            'color': '#A9A9A9',  # Darker light grey - protein-protein interactions
            'style': 'solid',
            'width': 1.5,
            'alpha': 0.5,
            'label': 'PPI'
        },
        
        # Unknown/fallback
        'Unknown': {
            'color': '#555555',  # Dark gray
            'style': 'solid',
            'width': 1.0,
            'alpha': 0.4,
            'label': 'Unknown'
        }
    }

# %%
import os
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import FancyArrowPatch
from matplotlib.lines import Line2D
from matplotlib.patches import Patch


def draw_subnetwork(module, target_genes, TF_regulators, metabolite_regulators,
                    PKN_df, PKN_nx, name_to_hmdb):
    """
    Draw subnetwork with clearer arrows, dots, and spacing.
    Uses edge categories and node types for styling.
    """

    # === Setup ===
    hmdb_to_name = {v: k for k, v in name_to_hmdb.items()}
    print(f'Module {module}: {len(metabolite_regulators)} metabolites, '
          f'{len(TF_regulators)} TFs, {len(target_genes)} targets.')

    to_draw = nx.Graph()
    edge_info = {}
    met_regs = []

    # --- STEP 1: Metabolite regulators ---
    for reg in metabolite_regulators:
        if reg not in name_to_hmdb:
            continue
        regulator = name_to_hmdb[reg]
        met_regs.append(regulator)
        if regulator not in PKN_nx:
            continue
        to_draw.add_node(regulator)
        for target in target_genes:
            try:
                if nx.shortest_path_length(PKN_nx, source=regulator, target=target) == 1:
                    to_draw.add_nodes_from([regulator, target])
                    to_draw.add_edge(regulator, target)
                    source, edge_type, category = get_edge_source_and_type(PKN_df, regulator, target)
                    edge_info[(regulator, target)] = {'source': source, 'type': edge_type, 'category': category}
            except (nx.NetworkXNoPath, nx.NodeNotFound):
                continue

    # --- STEP 2: TF regulators (PPI edges) ---
    for TF in TF_regulators:
        for regulator in met_regs:
            try:
                length = nx.shortest_path_length(PKN_nx, source=TF, target=regulator)
                if length <= 2:
                    path = nx.shortest_path(PKN_nx, source=TF, target=regulator)
                    for i in range(len(path) - 1):
                        u, v = path[i], path[i + 1]
                        to_draw.add_edge(u, v)
                        source, edge_type, category = get_edge_source_and_type(PKN_df, u, v)
                        edge_info[(u, v)] = {'source': source, 'type': edge_type, 'category': category}
            except (nx.NetworkXNoPath, nx.NodeNotFound):
                continue

    # --- STEP 3: Add edges among included nodes ---
    subgraph = PKN_nx.subgraph(to_draw.nodes())
    for u, v in subgraph.edges():
        if not to_draw.has_edge(u, v):
            to_draw.add_edge(u, v)
            source, edge_type, category = get_edge_source_and_type(PKN_df, u, v)
            edge_info[(u, v)] = {'source': source, 'type': edge_type, 'category': category}

    to_draw.remove_edges_from(nx.selfloop_edges(to_draw))
    disconnected = [n for n in to_draw if to_draw.degree(n) == 0]
    to_draw.remove_nodes_from(disconnected)

    if not to_draw.nodes:
        print(f"No valid connections for module {module}.")
        return

    # === Layout ===
    pos = nx.spring_layout(to_draw, k=1.8, iterations=200, seed=42)

    # === Node categories ===
    hmdb_nodes = [n for n in to_draw if n in name_to_hmdb.values()]
    tf_nodes = [n for n in to_draw if n in TF_regulators]
    target_nodes = [n for n in to_draw if n in target_genes]
    bridge_nodes = [n for n in to_draw if n not in hmdb_nodes + tf_nodes + target_nodes]

    # === Figure ===
    fig, ax = plt.subplots(figsize=(8, 6))
    edge_styles = get_edge_style_mapping()

    # === Draw nodes ===
    nx.draw_networkx_nodes(
        to_draw, pos,
        nodelist=tf_nodes,
        node_color="lightgreen",
        node_size=800,
        node_shape='o',
        ax=ax
    )
    nx.draw_networkx_nodes(
        to_draw, pos,
        nodelist=target_nodes,
        node_color="orange",
        node_size=800,
        node_shape='o',
        ax=ax
    )
    nx.draw_networkx_nodes(
        to_draw, pos,
        nodelist=bridge_nodes,
        node_color="lightgrey",
        node_size=700,
        node_shape='o',
        ax=ax
    )
    # Metabolites are represented only by their label boxes, not as separate nodes

    # === Draw edges ===
    for category, style in edge_styles.items():
        edges_of_category = [
            (u, v) for (u, v) in to_draw.edges()
            if edge_info.get((u, v), {}).get("category") == category
            or edge_info.get((v, u), {}).get("category") == category
        ]
        if not edges_of_category:
            continue

        if category == "Metabolic_pathway":
            # Draw line ending in a dot at the edge of the target node
            # Orient: metabolite -> target
            for u, v in edges_of_category:
                # Determine direction: metabolite should be source
                if u in hmdb_nodes:
                    source, target = u, v
                elif v in hmdb_nodes:
                    source, target = v, u
                else:
                    # If neither is metabolite, just use u,v
                    source, target = u, v
                
                p1 = np.array(pos[source])
                p2 = np.array(pos[target])
                vec = p2 - p1
                dist = np.linalg.norm(vec)
                if dist == 0:
                    continue
                vec /= dist
                
                # Adjust node radius based on node type
                # Metabolites are squares with size 900, others are circles with size 700-800
                if target in hmdb_nodes:
                    node_radius = 0.065  # Slightly larger for metabolites
                else:
                    node_radius = 0.055
                
                # Stop line at node boundary
                p2_adj = p2 - vec * node_radius
                
                # Draw the line
                ax.plot([p1[0], p2_adj[0]], [p1[1], p2_adj[1]],
                        color=style["color"], linewidth=style["width"], 
                        alpha=style["alpha"], zorder=1)
                
                # Place dot exactly at the node boundary
                dot_point = p2 - vec * node_radius
                ax.plot(dot_point[0], dot_point[1], "o",
                        color=style["color"], markersize=8, 
                        markerfacecolor=style["color"],
                        markeredgecolor='black', markeredgewidth=0.5,
                        alpha=style["alpha"], zorder=3)

        elif category == "Causal":
            # Draw arrows from metabolite to target
            for u, v in edges_of_category:
                # Determine direction: arrow should point from metabolite to target
                start, end = (u, v) if u in hmdb_nodes else (v, u)
                p1 = np.array(pos[start])
                p2 = np.array(pos[end])
                vec = p2 - p1
                dist = np.linalg.norm(vec)
                if dist == 0:
                    continue
                vec /= dist
                
                # Adjust for node sizes
                start_radius = 0.065 if start in hmdb_nodes else 0.055
                end_radius = 0.065 if end in hmdb_nodes else 0.055
                
                p1_adj = p1 + vec * start_radius
                p2_adj = p2 - vec * end_radius
                
                arrow = FancyArrowPatch(
                    p1_adj, p2_adj,
                    arrowstyle='-|>',
                    color=style["color"],
                    linewidth=style["width"],
                    alpha=style["alpha"],
                    mutation_scale=15,
                    connectionstyle='arc3,rad=0',
                    shrinkA=0, shrinkB=0,
                    zorder=2
                )
                ax.add_patch(arrow)

        else:
            # Draw simple edges for PPI, Ambiguous, and Unknown
            nx.draw_networkx_edges(
                to_draw, pos,
                edgelist=edges_of_category,
                edge_color=style["color"],
                style=style["style"],
                width=style["width"],
                alpha=style["alpha"],
                arrows=False,
                ax=ax
            )
    
    # === Labels ===
    metabolite_labels = {n: hmdb_to_name.get(n, n) for n in hmdb_nodes}
    nx.draw_networkx_labels(to_draw, pos, labels=metabolite_labels,
                            font_size=6, font_weight='bold',
                            bbox=dict(boxstyle='round,pad=0.4', fc='red', ec='none', alpha=0.7), ax=ax)
    other_labels = {n: n for n in to_draw if n not in hmdb_nodes}
    nx.draw_networkx_labels(to_draw, pos, labels=other_labels, font_size=5, font_weight='bold', ax=ax)

    # === Legends ===
    edge_legend_elements = create_edge_legend_by_category(ax, edge_styles, edge_info)
    node_legend_elements = create_node_legend(ax,
                                              has_metabolites=bool(hmdb_nodes),
                                              has_tfs=bool(tf_nodes),
                                              has_targets=bool(target_nodes),
                                              has_bridge=bool(bridge_nodes))
    legend_handles = edge_legend_elements + [Line2D([], [], color='none', label='')] + node_legend_elements
    ax.legend(handles=legend_handles, loc='upper left', bbox_to_anchor=(1.01, 1), fontsize=6,
              framealpha=0.9, borderpad=0.5, labelspacing=0.3, handlelength=1.5)

    # === Finalize ===
    plt.title(f'Module {module} - Subnetwork in LemonIte PKN\n'
              f'({len(to_draw.nodes())} nodes, {len(to_draw.edges())} edges)', fontsize=10)
    plt.axis('off')
    plt.tight_layout()

    os.makedirs('./Networks/subnetworks', exist_ok=True)
    plt.savefig(f'./Networks/subnetworks/graph_{module}_categorized_clean.png', dpi=200, bbox_inches='tight')
    plt.close()

    print_edge_statistics(edge_info)
    export_to_cytoscape_with_categories(to_draw, module, hmdb_to_name, TF_regulators, target_genes, edge_info, PKN_df)


# Update the main loop to pass both PKN DataFrame and NetworkX graph
for module in module2mets.keys():
    try:
        draw_subnetwork(
            module, 
            module2genes[module], 
            module2TFs[module], 
            module2mets[module],
            PKN,  # Pass DataFrame
            PKN.nx,  # Pass NetworkX graph
            name_to_hmdb
        )
    except KeyError:
        print(f'Module {module} not found in the mapping file')
        continue
    except Exception as e:
        print(f'An error occurred while processing module {module}: {e}')
        import traceback
        traceback.print_exc()
        continue
# Out:
# Module 0: 10 metabolites, 1 TFs, 100 targets.
# No valid connections for module 0.
# Module 1: 9 metabolites, 8 TFs, 71 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 17
#   Metabolic_pathway: 7
#   Causal: 1
#
# By Type:
#   PPI: 17
#   metabolite-gene: 8
#
# By Source:
#   BioGRID_genes: 9
#   STRING: 8
#   Human1_GEM_dist2: 7
#   LINCS: 1
#
# Cytoscape files with categorized edges saved for module 1:
#   Edges: ./Networks/cytoscape/module_1_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_1_attributes.tsv
# Module 10: 5 metabolites, 4 TFs, 42 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 3
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 3
#   metabolite-gene: 1
#
# By Source:
#   BioGRID_genes: 2
#   STRING: 1
#   Human1_GEM_dist2: 1
#
# Cytoscape files with categorized edges saved for module 10:
#   Edges: ./Networks/cytoscape/module_10_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_10_attributes.tsv
# Module 11: 8 metabolites, 8 TFs, 52 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 7
#   Metabolic_pathway: 2
#   Ambiguous: 1
#   Causal: 1
#
# By Type:
#   PPI: 7
#   metabolite-gene: 4
#
# By Source:
#   BioGRID_genes: 5
#   Human1_GEM_dist2: 2
#   STRING: 2
#   UniProtKB: 1
#   chEMBL: 1
#
# Cytoscape files with categorized edges saved for module 11:
#   Edges: ./Networks/cytoscape/module_11_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_11_attributes.tsv
# Module 12: 7 metabolites, 1 TFs, 46 targets.
# No valid connections for module 12.
# Module 13: 8 metabolites, 1 TFs, 53 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 2
#
# By Type:
#   metabolite-gene: 2
#
# By Source:
#   Human1_GEM_dist2: 2
#
# Cytoscape files with categorized edges saved for module 13:
#   Edges: ./Networks/cytoscape/module_13_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_13_attributes.tsv
# Module 14: 5 metabolites, 5 TFs, 79 targets.
# No valid connections for module 14.
# Module 15: 7 metabolites, 9 TFs, 130 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 9
#
# By Type:
#   PPI: 12
#   metabolite-gene: 9
#
# By Source:
#   Human1_GEM_dist2: 9
#   BioGRID_genes: 7
#   STRING: 5
#
# Cytoscape files with categorized edges saved for module 15:
#   Edges: ./Networks/cytoscape/module_15_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_15_attributes.tsv
# Module 16: 6 metabolites, 9 TFs, 52 targets.
# No valid connections for module 16.
# Module 17: 6 metabolites, 6 TFs, 65 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 14
#   Causal: 2
#   Metabolic_pathway: 2
#
# By Type:
#   PPI: 14
#   metabolite-gene: 4
#
# By Source:
#   BioGRID_genes: 10
#   STRING: 4
#   LINCS: 2
#   Human1_GEM_dist2: 2
#
# Cytoscape files with categorized edges saved for module 17:
#   Edges: ./Networks/cytoscape/module_17_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_17_attributes.tsv
# Module 18: 6 metabolites, 3 TFs, 36 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 5
#   PPI: 4
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 6
#   PPI: 4
#
# By Source:
#   Human1_GEM_dist2: 5
#   BioGRID_genes: 3
#   MetalinksDB: 1
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 18:
#   Edges: ./Networks/cytoscape/module_18_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_18_attributes.tsv
# Module 19: 9 metabolites, 8 TFs, 50 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 38
#   Metabolic_pathway: 7
#   Ambiguous: 3
#   Causal: 2
#
# By Type:
#   PPI: 38
#   metabolite-gene: 12
#
# By Source:
#   STRING: 24
#   BioGRID_genes: 14
#   Human1_GEM_dist2: 7
#   LINCS: 2
#   UniProtKB: 2
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 19:
#   Edges: ./Networks/cytoscape/module_19_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_19_attributes.tsv
# Module 2: 11 metabolites, 5 TFs, 103 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 21
#   PPI: 21
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 22
#   PPI: 21
#
# By Source:
#   Human1_GEM_dist2: 16
#   STRING: 13
#   BioGRID_genes: 8
#   Human1_GEM_dist1: 5
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 2:
#   Edges: ./Networks/cytoscape/module_2_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_2_attributes.tsv
# Module 20: 11 metabolites, 5 TFs, 213 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 7
#   PPI: 5
#
# By Type:
#   metabolite-gene: 7
#   PPI: 5
#
# By Source:
#   Human1_GEM_dist2: 7
#   BioGRID_genes: 3
#   STRING: 2
#
# Cytoscape files with categorized edges saved for module 20:
#   Edges: ./Networks/cytoscape/module_20_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_20_attributes.tsv
# Module 21: 5 metabolites, 4 TFs, 84 targets.
# No valid connections for module 21.
# Module 22: 6 metabolites, 4 TFs, 45 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 10
#   PPI: 8
#   Causal: 1
#
# By Type:
#   metabolite-gene: 11
#   PPI: 8
#
# By Source:
#   Human1_GEM_dist2: 9
#   STRING: 5
#   BioGRID_genes: 3
#   Human1_GEM_dist1: 1
#   chEMBL: 1
#
# Cytoscape files with categorized edges saved for module 22:
#   Edges: ./Networks/cytoscape/module_22_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_22_attributes.tsv
# Module 23: 9 metabolites, 4 TFs, 110 targets.
# No valid connections for module 23.
# Module 24: 8 metabolites, 7 TFs, 46 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 4
#   Causal: 1
#   Ambiguous: 1
#
# By Type:
#   PPI: 4
#   metabolite-gene: 2
#
# By Source:
#   BioGRID_genes: 3
#   STRING: 1
#   chEMBL: 1
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 24:
#   Edges: ./Networks/cytoscape/module_24_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_24_attributes.tsv
# Module 25: 5 metabolites, 6 TFs, 49 targets.
# No valid connections for module 25.
# Module 26: 5 metabolites, 6 TFs, 46 targets.
# No valid connections for module 26.
# Module 27: 4 metabolites, 6 TFs, 43 targets.
# No valid connections for module 27.
# Module 28: 4 metabolites, 5 TFs, 40 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 7
#   Ambiguous: 3
#   Causal: 2
#
# By Type:
#   metabolite-gene: 12
#   PPI: 12
#
# By Source:
#   Human1_GEM_dist2: 7
#   STRING: 7
#   BioGRID_genes: 5
#   UniProtKB: 3
#   LINCS: 1
#   chEMBL: 1
#
# Cytoscape files with categorized edges saved for module 28:
#   Edges: ./Networks/cytoscape/module_28_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_28_attributes.tsv
# Module 29: 5 metabolites, 6 TFs, 36 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 7
#   Metabolic_pathway: 3
#   Ambiguous: 2
#   Causal: 1
#
# By Type:
#   PPI: 7
#   metabolite-gene: 6
#
# By Source:
#   BioGRID_genes: 7
#   Human1_GEM_dist2: 3
#   UniProtKB: 2
#   chEMBL: 1
#
# Cytoscape files with categorized edges saved for module 29:
#   Edges: ./Networks/cytoscape/module_29_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_29_attributes.tsv
# Module 3: 7 metabolites, 2 TFs, 64 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 13
#   Metabolic_pathway: 5
#   Ambiguous: 2
#   Causal: 2
#
# By Type:
#   PPI: 13
#   metabolite-gene: 9
#
# By Source:
#   BioGRID_genes: 9
#   Human1_GEM_dist2: 5
#   STRING: 4
#   STITCH: 2
#   chEMBL: 1
#   LINCS: 1
#
# Cytoscape files with categorized edges saved for module 3:
#   Edges: ./Networks/cytoscape/module_3_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_3_attributes.tsv
# Module 30: 3 metabolites, 4 TFs, 23 targets.
# No valid connections for module 30.
# Module 31: 6 metabolites, 7 TFs, 23 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 8
#   Metabolic_pathway: 4
#   Ambiguous: 1
#
# By Type:
#   PPI: 8
#   metabolite-gene: 5
#
# By Source:
#   STRING: 6
#   Human1_GEM_dist2: 4
#   BioGRID_genes: 2
#   UniProtKB: 1
#
# Cytoscape files with categorized edges saved for module 31:
#   Edges: ./Networks/cytoscape/module_31_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_31_attributes.tsv
# Module 32: 5 metabolites, 4 TFs, 29 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 2
#   PPI: 1
#
# By Type:
#   metabolite-gene: 2
#   PPI: 1
#
# By Source:
#   Human1_GEM_dist2: 2
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 32:
#   Edges: ./Networks/cytoscape/module_32_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_32_attributes.tsv
# Module 33: 7 metabolites, 3 TFs, 23 targets.
# No valid connections for module 33.
# Module 34: 6 metabolites, 4 TFs, 28 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 5
#   Metabolic_pathway: 4
#
# By Type:
#   PPI: 5
#   metabolite-gene: 4
#
# By Source:
#   STRING: 5
#   Human1_GEM_dist2: 2
#   Human1_GEM_dist1: 2
#
# Cytoscape files with categorized edges saved for module 34:
#   Edges: ./Networks/cytoscape/module_34_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_34_attributes.tsv
# Module 35: 7 metabolites, 5 TFs, 33 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 7
#   Metabolic_pathway: 5
#   Causal: 1
#
# By Type:
#   PPI: 7
#   metabolite-gene: 6
#
# By Source:
#   BioGRID_genes: 7
#   Human1_GEM_dist2: 5
#   chEMBL: 1
#
# Cytoscape files with categorized edges saved for module 35:
#   Edges: ./Networks/cytoscape/module_35_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_35_attributes.tsv
# Module 36: 2 metabolites, 3 TFs, 28 targets.
# No valid connections for module 36.
# Module 37: 5 metabolites, 1 TFs, 35 targets.
# No valid connections for module 37.
# Module 38: 6 metabolites, 7 TFs, 26 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 4
#   PPI: 3
#
# By Type:
#   metabolite-gene: 4
#   PPI: 3
#
# By Source:
#   Human1_GEM_dist2: 4
#   STRING: 2
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 38:
#   Edges: ./Networks/cytoscape/module_38_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_38_attributes.tsv
# Module 39: 3 metabolites, 5 TFs, 27 targets.
# No valid connections for module 39.
# Module 4: 7 metabolites, 9 TFs, 151 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 22
#   Metabolic_pathway: 8
#   Causal: 1
#   Ambiguous: 1
#
# By Type:
#   PPI: 22
#   metabolite-gene: 10
#
# By Source:
#   BioGRID_genes: 13
#   STRING: 9
#   Human1_GEM_dist2: 8
#   chEMBL: 1
#   UniProtKB: 1
#
# Cytoscape files with categorized edges saved for module 4:
#   Edges: ./Networks/cytoscape/module_4_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_4_attributes.tsv
# Module 40: 4 metabolites, 1 TFs, 49 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 8
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 9
#
# By Source:
#   Human1_GEM_dist2: 8
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 40:
#   Edges: ./Networks/cytoscape/module_40_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_40_attributes.tsv
# Module 41: 5 metabolites, 3 TFs, 21 targets.
# No valid connections for module 41.
# Module 42: 7 metabolites, 2 TFs, 30 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 1
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 1
#   metabolite-gene: 1
#
# By Source:
#   STRING: 1
#   Human1_GEM_dist2: 1
#
# Cytoscape files with categorized edges saved for module 42:
#   Edges: ./Networks/cytoscape/module_42_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_42_attributes.tsv
# Module 43: 6 metabolites, 5 TFs, 50 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 6
#   Metabolic_pathway: 4
#   Ambiguous: 2
#
# By Type:
#   metabolite-gene: 6
#   PPI: 6
#
# By Source:
#   BioGRID_genes: 5
#   Human1_GEM_dist2: 4
#   MetalinksDB: 1
#   BioGRID: 1
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 43:
#   Edges: ./Networks/cytoscape/module_43_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_43_attributes.tsv
# Module 44: 7 metabolites, 6 TFs, 30 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 19
#   Metabolic_pathway: 16
#   Ambiguous: 2
#
# By Type:
#   PPI: 19
#   metabolite-gene: 18
#
# By Source:
#   Human1_GEM_dist2: 14
#   STRING: 12
#   BioGRID_genes: 7
#   Human1_GEM_dist1: 2
#   BioGRID: 1
#   MetalinksDB: 1
#
# Cytoscape files with categorized edges saved for module 44:
#   Edges: ./Networks/cytoscape/module_44_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_44_attributes.tsv
# Module 45: 4 metabolites, 5 TFs, 45 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 7
#   PPI: 5
#
# By Type:
#   metabolite-gene: 7
#   PPI: 5
#
# By Source:
#   Human1_GEM_dist2: 6
#   STRING: 4
#   Human1_GEM_dist1: 1
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 45:
#   Edges: ./Networks/cytoscape/module_45_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_45_attributes.tsv
# Module 46: 6 metabolites, 4 TFs, 49 targets.
# No valid connections for module 46.
# Module 47: 4 metabolites, 2 TFs, 26 targets.
# No valid connections for module 47.
# Module 48: 1 metabolites, 7 TFs, 31 targets.
# No valid connections for module 48.
# Module 49: 8 metabolites, 5 TFs, 57 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 7
#   Ambiguous: 2
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 7
#   metabolite-gene: 3
#
# By Source:
#   BioGRID_genes: 6
#   BioGRID: 2
#   Human1_GEM_dist2: 1
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 49:
#   Edges: ./Networks/cytoscape/module_49_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_49_attributes.tsv
# Module 5: 7 metabolites, 5 TFs, 62 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 11
#   Metabolic_pathway: 3
#   Causal: 3
#
# By Type:
#   PPI: 11
#   metabolite-gene: 6
#
# By Source:
#   STRING: 6
#   BioGRID_genes: 5
#   Human1_GEM_dist2: 3
#   chEMBL: 2
#   LINCS: 1
#
# Cytoscape files with categorized edges saved for module 5:
#   Edges: ./Networks/cytoscape/module_5_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_5_attributes.tsv
# Module 50: 2 metabolites, 3 TFs, 23 targets.
# No valid connections for module 50.
# Module 51: 7 metabolites, 2 TFs, 20 targets.
# No valid connections for module 51.
# Module 52: 11 metabolites, 4 TFs, 24 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 10
#   PPI: 9
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 11
#   PPI: 9
#
# By Source:
#   Human1_GEM_dist2: 10
#   BioGRID_genes: 6
#   STRING: 3
#   UniProtKB: 1
#
# Cytoscape files with categorized edges saved for module 52:
#   Edges: ./Networks/cytoscape/module_52_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_52_attributes.tsv
# Module 53: 5 metabolites, 7 TFs, 29 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 26
#   Metabolic_pathway: 17
#   Ambiguous: 5
#
# By Type:
#   PPI: 26
#   metabolite-gene: 22
#
# By Source:
#   Human1_GEM_dist2: 17
#   STRING: 15
#   BioGRID_genes: 11
#   UniProtKB: 3
#   BioGRID: 2
#
# Cytoscape files with categorized edges saved for module 53:
#   Edges: ./Networks/cytoscape/module_53_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_53_attributes.tsv
# Module 54: 2 metabolites, 2 TFs, 17 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 3
#   Metabolic_pathway: 3
#
# By Type:
#   PPI: 3
#   metabolite-gene: 3
#
# By Source:
#   Human1_GEM_dist2: 3
#   BioGRID_genes: 2
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 54:
#   Edges: ./Networks/cytoscape/module_54_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_54_attributes.tsv
# Module 55: 3 metabolites, 7 TFs, 99 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 9
#   Metabolic_pathway: 7
#
# By Type:
#   PPI: 9
#   metabolite-gene: 7
#
# By Source:
#   Human1_GEM_dist2: 7
#   STRING: 7
#   BioGRID_genes: 2
#
# Cytoscape files with categorized edges saved for module 55:
#   Edges: ./Networks/cytoscape/module_55_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_55_attributes.tsv
# Module 56: 6 metabolites, 4 TFs, 26 targets.
# No valid connections for module 56.
# Module 57: 7 metabolites, 2 TFs, 17 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 1
#
# By Type:
#   metabolite-gene: 1
#
# By Source:
#   Human1_GEM_dist1: 1
#
# Cytoscape files with categorized edges saved for module 57:
#   Edges: ./Networks/cytoscape/module_57_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_57_attributes.tsv
# Module 58: 4 metabolites, 4 TFs, 13 targets.
# No valid connections for module 58.
# Module 59: 7 metabolites, 9 TFs, 29 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 11
#   Metabolic_pathway: 7
#
# By Type:
#   PPI: 11
#   metabolite-gene: 7
#
# By Source:
#   BioGRID_genes: 9
#   Human1_GEM_dist2: 7
#   STRING: 2
#
# Cytoscape files with categorized edges saved for module 59:
#   Edges: ./Networks/cytoscape/module_59_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_59_attributes.tsv
# Module 6: 9 metabolites, 7 TFs, 52 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 25
#   Metabolic_pathway: 12
#   Ambiguous: 3
#   Causal: 1
#
# By Type:
#   PPI: 25
#   metabolite-gene: 16
#
# By Source:
#   BioGRID_genes: 14
#   Human1_GEM_dist2: 12
#   STRING: 11
#   LINCS: 1
#   UniProtKB: 1
#   MetalinksDB: 1
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 6:
#   Edges: ./Networks/cytoscape/module_6_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_6_attributes.tsv
# Module 60: 4 metabolites, 4 TFs, 25 targets.
# No valid connections for module 60.
# Module 61: 6 metabolites, 5 TFs, 39 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 6
#   Causal: 1
#   Ambiguous: 1
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 6
#   metabolite-gene: 3
#
# By Source:
#   BioGRID_genes: 4
#   STRING: 2
#   chEMBL: 1
#   BioGRID: 1
#   Human1_GEM_dist2: 1
#
# Cytoscape files with categorized edges saved for module 61:
#   Edges: ./Networks/cytoscape/module_61_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_61_attributes.tsv
# Module 62: 7 metabolites, 8 TFs, 21 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 13
#   Metabolic_pathway: 6
#
# By Type:
#   PPI: 13
#   metabolite-gene: 6
#
# By Source:
#   BioGRID_genes: 7
#   Human1_GEM_dist2: 6
#   STRING: 6
#
# Cytoscape files with categorized edges saved for module 62:
#   Edges: ./Networks/cytoscape/module_62_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_62_attributes.tsv
# Module 63: 5 metabolites, 4 TFs, 16 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 6
#
# By Type:
#   PPI: 12
#   metabolite-gene: 6
#
# By Source:
#   STRING: 9
#   Human1_GEM_dist2: 5
#   BioGRID_genes: 3
#   Human1_GEM_dist1: 1
#
# Cytoscape files with categorized edges saved for module 63:
#   Edges: ./Networks/cytoscape/module_63_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_63_attributes.tsv
# Module 64: 6 metabolites, 2 TFs, 15 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 2
#   Causal: 1
#
# By Type:
#   PPI: 2
#   metabolite-gene: 1
#
# By Source:
#   STRING: 1
#   chEMBL: 1
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 64:
#   Edges: ./Networks/cytoscape/module_64_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_64_attributes.tsv
# Module 65: 4 metabolites, 5 TFs, 33 targets.
# No valid connections for module 65.
# Module 66: 4 metabolites, 2 TFs, 20 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 6
#   Ambiguous: 2
#
# By Type:
#   PPI: 6
#   metabolite-gene: 2
#
# By Source:
#   BioGRID_genes: 3
#   STRING: 3
#   MetalinksDB: 1
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 66:
#   Edges: ./Networks/cytoscape/module_66_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_66_attributes.tsv
# Module 67: 6 metabolites, 4 TFs, 13 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 3
#   Metabolic_pathway: 2
#
# By Type:
#   PPI: 3
#   metabolite-gene: 2
#
# By Source:
#   Human1_GEM_dist2: 2
#   BioGRID_genes: 2
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 67:
#   Edges: ./Networks/cytoscape/module_67_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_67_attributes.tsv
# Module 68: 4 metabolites, 10 TFs, 15 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 5
#   Metabolic_pathway: 4
#
# By Type:
#   PPI: 5
#   metabolite-gene: 4
#
# By Source:
#   Human1_GEM_dist2: 4
#   STRING: 3
#   BioGRID_genes: 2
#
# Cytoscape files with categorized edges saved for module 68:
#   Edges: ./Networks/cytoscape/module_68_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_68_attributes.tsv
# Module 69: 7 metabolites, 1 TFs, 12 targets.
# No valid connections for module 69.
# Module 7: 4 metabolites, 5 TFs, 135 targets.
# No valid connections for module 7.
# Module 70: 4 metabolites, 5 TFs, 17 targets.
# No valid connections for module 70.
# Module 71: 2 metabolites, 3 TFs, 33 targets.
# No valid connections for module 71.
# Module 72: 5 metabolites, 3 TFs, 16 targets.
# No valid connections for module 72.
# Module 73: 3 metabolites, 3 TFs, 14 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 3
#   PPI: 2
#
# By Type:
#   metabolite-gene: 3
#   PPI: 2
#
# By Source:
#   Human1_GEM_dist2: 3
#   STRING: 2
#
# Cytoscape files with categorized edges saved for module 73:
#   Edges: ./Networks/cytoscape/module_73_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_73_attributes.tsv
# Module 74: 5 metabolites, 4 TFs, 10 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 13
#   Metabolic_pathway: 7
#   Ambiguous: 1
#
# By Type:
#   PPI: 13
#   metabolite-gene: 8
#
# By Source:
#   BioGRID_genes: 9
#   Human1_GEM_dist2: 7
#   STRING: 4
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 74:
#   Edges: ./Networks/cytoscape/module_74_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_74_attributes.tsv
# Module 75: 5 metabolites, 5 TFs, 27 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 3
#   Metabolic_pathway: 2
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 3
#   PPI: 3
#
# By Source:
#   Human1_GEM_dist2: 2
#   STRING: 2
#   UniProtKB: 1
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 75:
#   Edges: ./Networks/cytoscape/module_75_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_75_attributes.tsv
# Module 76: 4 metabolites, 6 TFs, 51 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 6
#   PPI: 2
#
# By Type:
#   metabolite-gene: 6
#   PPI: 2
#
# By Source:
#   Human1_GEM_dist2: 6
#   BioGRID_genes: 1
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 76:
#   Edges: ./Networks/cytoscape/module_76_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_76_attributes.tsv
# Module 77: 5 metabolites, 2 TFs, 17 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 2
#   PPI: 1
#
# By Type:
#   metabolite-gene: 2
#   PPI: 1
#
# By Source:
#   Human1_GEM_dist2: 2
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 77:
#   Edges: ./Networks/cytoscape/module_77_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_77_attributes.tsv
# Module 78: 4 metabolites, 6 TFs, 23 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 5
#   PPI: 5
#
# By Type:
#   metabolite-gene: 5
#   PPI: 5
#
# By Source:
#   Human1_GEM_dist2: 5
#   BioGRID_genes: 3
#   STRING: 2
#
# Cytoscape files with categorized edges saved for module 78:
#   Edges: ./Networks/cytoscape/module_78_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_78_attributes.tsv
# Module 79: 3 metabolites, 5 TFs, 10 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 9
#   Ambiguous: 1
#
# By Type:
#   PPI: 12
#   metabolite-gene: 10
#
# By Source:
#   BioGRID_genes: 8
#   Human1_GEM_dist2: 8
#   STRING: 4
#   Human1_GEM_dist1: 1
#   UniProtKB: 1
#
# Cytoscape files with categorized edges saved for module 79:
#   Edges: ./Networks/cytoscape/module_79_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_79_attributes.tsv
# Module 8: 7 metabolites, 7 TFs, 62 targets.
# No valid connections for module 8.
# Module 80: 5 metabolites, 4 TFs, 33 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 2
#   Ambiguous: 1
#
# By Type:
#   PPI: 2
#   metabolite-gene: 1
#
# By Source:
#   BioGRID_genes: 2
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 80:
#   Edges: ./Networks/cytoscape/module_80_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_80_attributes.tsv
# Module 81: 3 metabolites, 6 TFs, 18 targets.
# No valid connections for module 81.
# Module 82: 7 metabolites, 5 TFs, 22 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 1
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 1
#   metabolite-gene: 1
#
# By Source:
#   STRING: 1
#   Human1_GEM_dist2: 1
#
# Cytoscape files with categorized edges saved for module 82:
#   Edges: ./Networks/cytoscape/module_82_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_82_attributes.tsv
# Module 83: 7 metabolites, 2 TFs, 11 targets.
# No valid connections for module 83.
# Module 84: 8 metabolites, 6 TFs, 26 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 13
#   Metabolic_pathway: 6
#   Ambiguous: 2
#   Causal: 1
#
# By Type:
#   PPI: 13
#   metabolite-gene: 9
#
# By Source:
#   BioGRID_genes: 9
#   Human1_GEM_dist2: 6
#   STRING: 4
#   LINCS: 1
#   MetalinksDB: 1
#   BioGRID: 1
#
# Cytoscape files with categorized edges saved for module 84:
#   Edges: ./Networks/cytoscape/module_84_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_84_attributes.tsv
# Module 85: 6 metabolites, 4 TFs, 11 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 4
#   Ambiguous: 1
#   Metabolic_pathway: 1
#
# By Type:
#   PPI: 4
#   metabolite-gene: 2
#
# By Source:
#   BioGRID_genes: 3
#   BioGRID: 1
#   STRING: 1
#   Human1_GEM_dist2: 1
#
# Cytoscape files with categorized edges saved for module 85:
#   Edges: ./Networks/cytoscape/module_85_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_85_attributes.tsv
# Module 86: 4 metabolites, 3 TFs, 20 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 5
#   PPI: 5
#
# By Type:
#   metabolite-gene: 5
#   PPI: 5
#
# By Source:
#   Human1_GEM_dist2: 5
#   BioGRID_genes: 5
#
# Cytoscape files with categorized edges saved for module 86:
#   Edges: ./Networks/cytoscape/module_86_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_86_attributes.tsv
# Module 87: 7 metabolites, 5 TFs, 39 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 14
#   PPI: 7
#   Ambiguous: 1
#
# By Type:
#   metabolite-gene: 15
#   PPI: 7
#
# By Source:
#   Human1_GEM_dist2: 13
#   BioGRID_genes: 4
#   STRING: 3
#   UniProtKB: 1
#   Human1_GEM_dist1: 1
#
# Cytoscape files with categorized edges saved for module 87:
#   Edges: ./Networks/cytoscape/module_87_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_87_attributes.tsv
# Module 88: 5 metabolites, 4 TFs, 16 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 5
#   PPI: 3
#
# By Type:
#   metabolite-gene: 5
#   PPI: 3
#
# By Source:
#   Human1_GEM_dist2: 3
#   Human1_GEM_dist1: 2
#   BioGRID_genes: 2
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 88:
#   Edges: ./Networks/cytoscape/module_88_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_88_attributes.tsv
# Module 89: 9 metabolites, 4 TFs, 20 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 6
#   Ambiguous: 2
#
# By Type:
#   PPI: 12
#   metabolite-gene: 8
#
# By Source:
#   STRING: 7
#   Human1_GEM_dist2: 6
#   BioGRID_genes: 5
#   BioGRID: 1
#   UniProtKB: 1
#
# Cytoscape files with categorized edges saved for module 89:
#   Edges: ./Networks/cytoscape/module_89_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_89_attributes.tsv
# Module 9: 7 metabolites, 8 TFs, 74 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 25
#   Metabolic_pathway: 6
#   Causal: 1
#
# By Type:
#   PPI: 25
#   metabolite-gene: 7
#
# By Source:
#   STRING: 16
#   BioGRID_genes: 9
#   Human1_GEM_dist2: 5
#   Human1_GEM_dist1: 1
#   LINCS: 1
#
# Cytoscape files with categorized edges saved for module 9:
#   Edges: ./Networks/cytoscape/module_9_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_9_attributes.tsv
# Module 90: 5 metabolites, 3 TFs, 23 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 3
#   PPI: 3
#
# By Type:
#   metabolite-gene: 3
#   PPI: 3
#
# By Source:
#   Human1_GEM_dist2: 3
#   BioGRID_genes: 2
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 90:
#   Edges: ./Networks/cytoscape/module_90_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_90_attributes.tsv
# Module 91: 6 metabolites, 6 TFs, 13 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 12
#   Metabolic_pathway: 5
#
# By Type:
#   PPI: 12
#   metabolite-gene: 5
#
# By Source:
#   STRING: 7
#   Human1_GEM_dist2: 5
#   BioGRID_genes: 5
#
# Cytoscape files with categorized edges saved for module 91:
#   Edges: ./Networks/cytoscape/module_91_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_91_attributes.tsv
# Module 92: 2 metabolites, 4 TFs, 13 targets.
# No valid connections for module 92.
# Module 93: 8 metabolites, 11 TFs, 11 targets.
# No valid connections for module 93.
# Module 94: 6 metabolites, 6 TFs, 18 targets.
#
# === Edge Statistics ===
#
# By Category:
#   Metabolic_pathway: 2
#   PPI: 1
#
# By Type:
#   metabolite-gene: 2
#   PPI: 1
#
# By Source:
#   Human1_GEM_dist2: 2
#   BioGRID_genes: 1
#
# Cytoscape files with categorized edges saved for module 94:
#   Edges: ./Networks/cytoscape/module_94_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_94_attributes.tsv
# Module 95: 1 metabolites, 6 TFs, 11 targets.
# No valid connections for module 95.
# Module 96: 2 metabolites, 3 TFs, 13 targets.
#
# === Edge Statistics ===
#
# By Category:
#   PPI: 2
#   Metabolic_pathway: 2
#
# By Type:
#   PPI: 2
#   metabolite-gene: 2
#
# By Source:
#   Human1_GEM_dist2: 2
#   BioGRID_genes: 1
#   STRING: 1
#
# Cytoscape files with categorized edges saved for module 96:
#   Edges: ./Networks/cytoscape/module_96_edges_categorized.tsv
#   Attributes: ./Networks/cytoscape/module_96_attributes.tsv
